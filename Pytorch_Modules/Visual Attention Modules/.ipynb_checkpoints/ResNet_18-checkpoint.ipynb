# %%
import torch
from torch import nn
from torch.nn import functional as F
from d2l import torch as d2l
import torchvision as tv
import os
import numpy as np

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Residual(nn.Module):
    def __init__(self, input_channels, num_channels,
                 use_1x1conv=False, strides=1):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, num_channels,
                               kernel_size=3, padding=1, stride=strides)
        self.conv2 = nn.Conv2d(num_channels, num_channels,
                               kernel_size=3, padding=1)
        if use_1x1conv:
            self.conv3 = nn.Conv2d(input_channels, num_channels,
                                   kernel_size=1, stride=strides)
        else:
            self.conv3 = None
        self.bn1 = nn.BatchNorm2d(num_channels)
        self.bn2 = nn.BatchNorm2d(num_channels)

    def forward(self, X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = self.bn2(self.conv2(Y))
        if self.conv3:
            X = self.conv3(X)
        Y += X
        return F.relu(Y)

# %%
def resnet_block(input_channels, num_channels, num_residuals,
                 first_block=False):
    blk = []
    for i in range(num_residuals):
        if i == 0 and not first_block:
            blk.append(Residual(input_channels, num_channels,
                                use_1x1conv=True, strides=2))
        else:
            blk.append(Residual(num_channels, num_channels))
    return blk

# %%
b1 = nn.Sequential(nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
                   nn.BatchNorm2d(64), nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=1, padding=1))

# %%
b2 = nn.Sequential(*resnet_block(64, 64, 2, first_block=True))
b3 = nn.Sequential(*resnet_block(64, 128, 2))
b4 = nn.Sequential(*resnet_block(128, 256, 2))
b5 = nn.Sequential(*resnet_block(256, 512, 2))

# %%
net = nn.Sequential(b1, b2, b3, b4, b5,
                    nn.AdaptiveAvgPool2d((1,1)),
                    nn.Flatten(), nn.Dropout(0.5), nn.Linear(512, 10))

if device == 'cuda':
	net = torch.nn.DataParallel(net)

# %%
X = torch.rand(size=(1, 3, 32, 32))
for layer in net:
    X = layer(X)
    print(layer.__class__.__name__,'output shape:\t', X.shape)
# Out:
# Sequential output shape:	 torch.Size([1, 64, 32, 32])
# Sequential output shape:	 torch.Size([1, 64, 32, 32])
# Sequential output shape:	 torch.Size([1, 128, 16, 16])
# Sequential output shape:	 torch.Size([1, 256, 8, 8])
# Sequential output shape:	 torch.Size([1, 512, 4, 4])
# AdaptiveAvgPool2d output shape:	 torch.Size([1, 512, 1, 1])
# Flatten output shape:	 torch.Size([1, 512])
# Dropout output shape:	 torch.Size([1, 512])
# Linear output shape:	 torch.Size([1, 10])

# %%
def evaluate_accuracy_gpu(net, data_iter, device=None): 
    if isinstance(net, nn.Module):
        net.eval()  
        if not device:
            device = next(iter(net.parameters())).device
    metric = d2l.Accumulator(2)
    with torch.no_grad():
        for X, y in data_iter:
            if isinstance(X, list):
                X = [x.to(device) for x in X]
            else:
                X = X.to(device)
            y = y.to(device)
            metric.add(d2l.accuracy(net(X), y), y.numel())
    return metric[0] / metric[1]

# %%
def train_net(net, train_iter, test_iter, num_epochs, lr, device):
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            torch.nn.init.kaiming_uniform_(m.weight)
    net.apply(init_weights)
    print('training on', device)
    net.to(device)
    optimizer = torch.optim.SGD(params=net.parameters(),
                          lr=lr,
                          momentum=0.9,
                          weight_decay=0.001)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(
        optimizer, milestones=[50, 100, 150], gamma=0.1)
    loss = nn.CrossEntropyLoss()
    num_batches = len(train_iter)
    for epoch in range(num_epochs):
        metric = d2l.Accumulator(3)
        net.train()
        for i, (X, y) in enumerate(train_iter):
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            optimizer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
        scheduler.step()
        test_acc = evaluate_accuracy_gpu(net, test_iter)
        print(f'------- ------- Epoch{epoch+1}/{num_epochs} ------- -------')
        print(f'loss {train_l:.5f}, train acc {train_acc:.5f}, '
              f'test acc {test_acc:.5f}')

# %%
shape_aug = tv.transforms.RandomResizedCrop(
    (28, 28), scale=(0.1, 1), ratio=(0.5, 2))

color_aug = tv.transforms.ColorJitter(
    brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)

# %%
train_augs = tv.transforms.Compose([
    tv.transforms.RandomCrop(32, padding=4),
    tv.transforms.RandomHorizontalFlip(),
    tv.transforms.ToTensor(), shape_aug, color_aug
    tv.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

test_augs = tv.transforms.Compose([
    tv.transforms.ToTensor(),
    tv.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# %%
def load_cifar10(is_train, augs, batch_size):
    dataset = tv.datasets.CIFAR10(root="../data", train=is_train,
                                           transform=augs, download=True)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                    shuffle=is_train, num_workers=2)
    return dataloader

# %%
lr, num_epochs, batch_size = 0.01, 200, 128

# %%
train_iter = load_cifar10(True, train_augs, batch_size)
test_iter = load_cifar10(False, test_augs, batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_net(net, train_iter, test_iter, num_epochs, lr, device)
# Out:
# training on cuda
# ------- ------- Epoch1/250 ------- -------
# loss 2.01002, train acc 0.29260, test acc 0.40050
# ------- ------- Epoch2/250 ------- -------
# loss 1.67121, train acc 0.39310, test acc 0.48360
# ------- ------- Epoch3/250 ------- -------
# loss 1.55781, train acc 0.43690, test acc 0.51840
# ------- ------- Epoch4/250 ------- -------
# loss 1.47050, train acc 0.47250, test acc 0.56580
# ------- ------- Epoch5/250 ------- -------
# loss 1.39056, train acc 0.50182, test acc 0.60550
# ------- ------- Epoch6/250 ------- -------
# loss 1.32494, train acc 0.52848, test acc 0.61000
# ------- ------- Epoch7/250 ------- -------
# loss 1.26908, train acc 0.54834, test acc 0.58140
# ------- ------- Epoch8/250 ------- -------
# loss 1.21014, train acc 0.57414, test acc 0.65000
# ------- ------- Epoch9/250 ------- -------
# loss 1.17019, train acc 0.58704, test acc 0.65960
# ------- ------- Epoch10/250 ------- -------
# loss 1.13662, train acc 0.59808, test acc 0.71650
# ------- ------- Epoch11/250 ------- -------
# loss 1.09115, train acc 0.61770, test acc 0.73790
# ------- ------- Epoch12/250 ------- -------
# loss 1.06700, train acc 0.62618, test acc 0.73300
# ------- ------- Epoch13/250 ------- -------
# loss 1.03379, train acc 0.63808, test acc 0.74710
# ------- ------- Epoch14/250 ------- -------
# loss 1.00698, train acc 0.64866, test acc 0.78340
# ------- ------- Epoch15/250 ------- -------
# loss 0.98296, train acc 0.65522, test acc 0.74420
# ------- ------- Epoch16/250 ------- -------
# loss 0.96463, train acc 0.66724, test acc 0.78420
# ------- ------- Epoch17/250 ------- -------
# loss 0.94774, train acc 0.67082, test acc 0.78940
# ------- ------- Epoch18/250 ------- -------
# loss 0.93248, train acc 0.67676, test acc 0.79040
# ------- ------- Epoch19/250 ------- -------
# loss 0.90827, train acc 0.68534, test acc 0.80010
# ------- ------- Epoch20/250 ------- -------
# loss 0.90289, train acc 0.68608, test acc 0.77110
# ------- ------- Epoch21/250 ------- -------
# loss 0.88879, train acc 0.69140, test acc 0.82700
# ------- ------- Epoch22/250 ------- -------
# loss 0.87384, train acc 0.69828, test acc 0.80870
# ------- ------- Epoch23/250 ------- -------
# loss 0.85362, train acc 0.70398, test acc 0.80370
# ------- ------- Epoch24/250 ------- -------
# loss 0.84538, train acc 0.70702, test acc 0.81680
# ------- ------- Epoch25/250 ------- -------
# loss 0.83717, train acc 0.70976, test acc 0.81340
# ------- ------- Epoch26/250 ------- -------
# loss 0.83074, train acc 0.71562, test acc 0.83630
# ------- ------- Epoch27/250 ------- -------
# loss 0.82209, train acc 0.71660, test acc 0.79510
# ------- ------- Epoch28/250 ------- -------
# loss 0.81288, train acc 0.72088, test acc 0.82510
# ------- ------- Epoch29/250 ------- -------
# loss 0.80445, train acc 0.72224, test acc 0.84360
# ------- ------- Epoch30/250 ------- -------
# loss 0.79580, train acc 0.72444, test acc 0.83350
# ------- ------- Epoch31/250 ------- -------
# loss 0.78492, train acc 0.72784, test acc 0.84630
# ------- ------- Epoch32/250 ------- -------
# loss 0.77708, train acc 0.73170, test acc 0.80530
# ------- ------- Epoch33/250 ------- -------
# loss 0.76970, train acc 0.73372, test acc 0.84840
# ------- ------- Epoch34/250 ------- -------
# loss 0.76557, train acc 0.73708, test acc 0.84290
# ------- ------- Epoch35/250 ------- -------
# loss 0.76074, train acc 0.73950, test acc 0.85110
# ------- ------- Epoch36/250 ------- -------
# loss 0.75500, train acc 0.74042, test acc 0.82930
# ------- ------- Epoch37/250 ------- -------
# loss 0.75505, train acc 0.73848, test acc 0.85620
# ------- ------- Epoch38/250 ------- -------
# loss 0.74900, train acc 0.74346, test acc 0.84580
# ------- ------- Epoch39/250 ------- -------
# loss 0.74642, train acc 0.74360, test acc 0.84870
# ------- ------- Epoch40/250 ------- -------
# loss 0.73621, train acc 0.74840, test acc 0.84600
# ------- ------- Epoch41/250 ------- -------
# loss 0.73465, train acc 0.74680, test acc 0.84800
# ------- ------- Epoch42/250 ------- -------
# loss 0.72880, train acc 0.75002, test acc 0.86140
# ------- ------- Epoch43/250 ------- -------
# loss 0.71985, train acc 0.75448, test acc 0.86110
# ------- ------- Epoch44/250 ------- -------
# loss 0.72616, train acc 0.75084, test acc 0.84800
# ------- ------- Epoch45/250 ------- -------
# loss 0.72347, train acc 0.75104, test acc 0.87110
# ------- ------- Epoch46/250 ------- -------
# loss 0.71315, train acc 0.75290, test acc 0.86850
# ------- ------- Epoch47/250 ------- -------
# loss 0.71341, train acc 0.75566, test acc 0.84420
# ------- ------- Epoch48/250 ------- -------
# loss 0.70458, train acc 0.75680, test acc 0.83280
# ------- ------- Epoch49/250 ------- -------
# loss 0.70442, train acc 0.75670, test acc 0.85860
# ------- ------- Epoch50/250 ------- -------
# loss 0.71001, train acc 0.75602, test acc 0.85810
# ------- ------- Epoch51/250 ------- -------
# loss 0.70374, train acc 0.75702, test acc 0.85550
# ------- ------- Epoch52/250 ------- -------
# loss 0.69925, train acc 0.75796, test acc 0.86890
# ------- ------- Epoch53/250 ------- -------
# loss 0.69084, train acc 0.76176, test acc 0.85520
# ------- ------- Epoch54/250 ------- -------
# loss 0.69061, train acc 0.76198, test acc 0.85610
# ------- ------- Epoch55/250 ------- -------
# loss 0.69464, train acc 0.76078, test acc 0.87410
# ------- ------- Epoch56/250 ------- -------
# loss 0.68635, train acc 0.76490, test acc 0.85050
# ------- ------- Epoch57/250 ------- -------
# loss 0.69791, train acc 0.76054, test acc 0.87570
# ------- ------- Epoch58/250 ------- -------
# loss 0.68484, train acc 0.76620, test acc 0.87930
# ------- ------- Epoch59/250 ------- -------
# loss 0.68796, train acc 0.76400, test acc 0.85450
# ------- ------- Epoch60/250 ------- -------
# loss 0.68616, train acc 0.76440, test acc 0.87880
# ------- ------- Epoch61/250 ------- -------
# loss 0.68593, train acc 0.76646, test acc 0.87920
# ------- ------- Epoch62/250 ------- -------
# loss 0.67435, train acc 0.76888, test acc 0.86170
# ------- ------- Epoch63/250 ------- -------
# loss 0.68068, train acc 0.76428, test acc 0.87470
# ------- ------- Epoch64/250 ------- -------
# loss 0.67068, train acc 0.77026, test acc 0.87260
# ------- ------- Epoch65/250 ------- -------
# loss 0.67158, train acc 0.77098, test acc 0.87670
# ------- ------- Epoch66/250 ------- -------
# loss 0.55665, train acc 0.81192, test acc 0.91390
# ------- ------- Epoch67/250 ------- -------
# loss 0.51465, train acc 0.82520, test acc 0.91660
# ------- ------- Epoch68/250 ------- -------
# loss 0.49653, train acc 0.83310, test acc 0.91740
# ------- ------- Epoch69/250 ------- -------
# loss 0.47949, train acc 0.83670, test acc 0.91990
# ------- ------- Epoch70/250 ------- -------
# loss 0.48034, train acc 0.83672, test acc 0.92100
# ------- ------- Epoch71/250 ------- -------
# loss 0.47877, train acc 0.83704, test acc 0.92260
# ------- ------- Epoch72/250 ------- -------
# loss 0.47080, train acc 0.83976, test acc 0.92270
# ------- ------- Epoch73/250 ------- -------
# loss 0.47049, train acc 0.84068, test acc 0.92110
# ------- ------- Epoch74/250 ------- -------
# loss 0.45442, train acc 0.84556, test acc 0.92500
# ------- ------- Epoch75/250 ------- -------
# loss 0.45003, train acc 0.84772, test acc 0.92480
# ------- ------- Epoch76/250 ------- -------
# loss 0.44888, train acc 0.84712, test acc 0.92380
# ------- ------- Epoch77/250 ------- -------
# loss 0.44550, train acc 0.84838, test acc 0.92670
# ------- ------- Epoch78/250 ------- -------
# loss 0.44750, train acc 0.84740, test acc 0.92570
# ------- ------- Epoch79/250 ------- -------
# loss 0.43774, train acc 0.85118, test acc 0.92650
# ------- ------- Epoch80/250 ------- -------
# loss 0.44098, train acc 0.85036, test acc 0.92910
# ------- ------- Epoch81/250 ------- -------
# loss 0.43413, train acc 0.85376, test acc 0.92880
# ------- ------- Epoch82/250 ------- -------
# loss 0.43794, train acc 0.85080, test acc 0.93010
# ------- ------- Epoch83/250 ------- -------
# loss 0.42668, train acc 0.85418, test acc 0.92600
# ------- ------- Epoch84/250 ------- -------
# loss 0.42365, train acc 0.85590, test acc 0.92960
# ------- ------- Epoch85/250 ------- -------
# loss 0.42888, train acc 0.85386, test acc 0.93120
# ------- ------- Epoch86/250 ------- -------
# loss 0.42825, train acc 0.85410, test acc 0.92730
# ------- ------- Epoch87/250 ------- -------
# loss 0.42244, train acc 0.85604, test acc 0.92750
# ------- ------- Epoch88/250 ------- -------
# loss 0.42075, train acc 0.85790, test acc 0.92760
# ------- ------- Epoch89/250 ------- -------
# loss 0.42262, train acc 0.85522, test acc 0.92940
# ------- ------- Epoch90/250 ------- -------
# loss 0.41672, train acc 0.85884, test acc 0.92970
# ------- ------- Epoch91/250 ------- -------
# loss 0.41475, train acc 0.85904, test acc 0.93120
# ------- ------- Epoch92/250 ------- -------
# loss 0.41218, train acc 0.85948, test acc 0.93000
# ------- ------- Epoch93/250 ------- -------
# loss 0.40884, train acc 0.86160, test acc 0.92780
# ------- ------- Epoch94/250 ------- -------
# loss 0.40829, train acc 0.86122, test acc 0.92850
# ------- ------- Epoch95/250 ------- -------
# loss 0.40272, train acc 0.86308, test acc 0.92960
# ------- ------- Epoch96/250 ------- -------
# loss 0.40553, train acc 0.86270, test acc 0.93270
# ------- ------- Epoch97/250 ------- -------
# loss 0.40152, train acc 0.86516, test acc 0.93080
# ------- ------- Epoch98/250 ------- -------
# loss 0.39959, train acc 0.86488, test acc 0.92780
# ------- ------- Epoch99/250 ------- -------
# loss 0.40160, train acc 0.86240, test acc 0.92970
# ------- ------- Epoch100/250 ------- -------
# loss 0.40156, train acc 0.86334, test acc 0.93320
# ------- ------- Epoch101/250 ------- -------
# loss 0.40421, train acc 0.86220, test acc 0.92820
# ------- ------- Epoch102/250 ------- -------
# loss 0.39393, train acc 0.86590, test acc 0.93040
# ------- ------- Epoch103/250 ------- -------
# loss 0.39334, train acc 0.86760, test acc 0.92980
# ------- ------- Epoch104/250 ------- -------
# loss 0.38877, train acc 0.86712, test acc 0.93060
# ------- ------- Epoch105/250 ------- -------
# loss 0.39300, train acc 0.86594, test acc 0.93110
# ------- ------- Epoch106/250 ------- -------
# loss 0.39148, train acc 0.86656, test acc 0.92750
# ------- ------- Epoch107/250 ------- -------
# loss 0.38730, train acc 0.86766, test acc 0.93300
# ------- ------- Epoch108/250 ------- -------
# loss 0.38743, train acc 0.86908, test acc 0.92880
# ------- ------- Epoch109/250 ------- -------
# loss 0.38850, train acc 0.86748, test acc 0.92920
# ------- ------- Epoch110/250 ------- -------
# loss 0.38493, train acc 0.86908, test acc 0.93160
# ------- ------- Epoch111/250 ------- -------
# loss 0.39090, train acc 0.86668, test acc 0.93280
# ------- ------- Epoch112/250 ------- -------
# loss 0.38550, train acc 0.86910, test acc 0.93120
# ------- ------- Epoch113/250 ------- -------
# loss 0.38390, train acc 0.87008, test acc 0.93580
# ------- ------- Epoch114/250 ------- -------
# loss 0.38456, train acc 0.86902, test acc 0.92990
# ------- ------- Epoch115/250 ------- -------
# loss 0.38350, train acc 0.87012, test acc 0.93260
# ------- ------- Epoch116/250 ------- -------
# loss 0.38185, train acc 0.87016, test acc 0.93030
# ------- ------- Epoch117/250 ------- -------
# loss 0.38073, train acc 0.86910, test acc 0.93070
# ------- ------- Epoch118/250 ------- -------
# loss 0.38127, train acc 0.87238, test acc 0.93380
# ------- ------- Epoch119/250 ------- -------
# loss 0.37636, train acc 0.87132, test acc 0.93030
# ------- ------- Epoch120/250 ------- -------
# loss 0.38097, train acc 0.87140, test acc 0.93270
# ------- ------- Epoch121/250 ------- -------
# loss 0.37705, train acc 0.87216, test acc 0.93350
# ------- ------- Epoch122/250 ------- -------
# loss 0.37710, train acc 0.87216, test acc 0.93230
# ------- ------- Epoch123/250 ------- -------
# loss 0.37152, train acc 0.87196, test acc 0.93180
# ------- ------- Epoch124/250 ------- -------
# loss 0.37269, train acc 0.87242, test acc 0.92990
# ------- ------- Epoch125/250 ------- -------
# loss 0.37946, train acc 0.87136, test acc 0.93040
# ------- ------- Epoch126/250 ------- -------
# loss 0.37136, train acc 0.87314, test acc 0.92990
# ------- ------- Epoch127/250 ------- -------
# loss 0.37236, train acc 0.87408, test acc 0.93140
# ------- ------- Epoch128/250 ------- -------
# loss 0.37592, train acc 0.87260, test acc 0.92780
# ------- ------- Epoch129/250 ------- -------
# loss 0.36671, train acc 0.87390, test acc 0.93580
# ------- ------- Epoch130/250 ------- -------
# loss 0.36798, train acc 0.87498, test acc 0.93100
# ------- ------- Epoch131/250 ------- -------
# loss 0.34982, train acc 0.88162, test acc 0.93720
# ------- ------- Epoch132/250 ------- -------
# loss 0.33732, train acc 0.88580, test acc 0.93800
# ------- ------- Epoch133/250 ------- -------
# loss 0.33436, train acc 0.88724, test acc 0.93700
# ------- ------- Epoch134/250 ------- -------
# loss 0.33315, train acc 0.88654, test acc 0.93730
# ------- ------- Epoch135/250 ------- -------
# loss 0.32792, train acc 0.88966, test acc 0.93790
# ------- ------- Epoch136/250 ------- -------
# loss 0.32281, train acc 0.88990, test acc 0.93740
# ------- ------- Epoch137/250 ------- -------
# loss 0.32381, train acc 0.88974, test acc 0.93810
# ------- ------- Epoch138/250 ------- -------
# loss 0.33286, train acc 0.88746, test acc 0.93780
# ------- ------- Epoch139/250 ------- -------
# loss 0.31849, train acc 0.89156, test acc 0.93800
# ------- ------- Epoch140/250 ------- -------
# loss 0.32223, train acc 0.89030, test acc 0.93920
# ------- ------- Epoch141/250 ------- -------
# loss 0.32084, train acc 0.89206, test acc 0.93970
# ------- ------- Epoch142/250 ------- -------
# loss 0.32033, train acc 0.89122, test acc 0.93990
# ------- ------- Epoch143/250 ------- -------
# loss 0.31543, train acc 0.89322, test acc 0.94080
# ------- ------- Epoch144/250 ------- -------
# loss 0.31228, train acc 0.89404, test acc 0.94140
# ------- ------- Epoch145/250 ------- -------
# loss 0.31480, train acc 0.89178, test acc 0.93980
# ------- ------- Epoch146/250 ------- -------
# loss 0.31382, train acc 0.89440, test acc 0.93970
# ------- ------- Epoch147/250 ------- -------
# loss 0.31009, train acc 0.89606, test acc 0.94030
# ------- ------- Epoch148/250 ------- -------
# loss 0.31090, train acc 0.89480, test acc 0.93910
# ------- ------- Epoch149/250 ------- -------
# loss 0.31905, train acc 0.89248, test acc 0.93940
# ------- ------- Epoch150/250 ------- -------
# loss 0.30859, train acc 0.89634, test acc 0.94160
# ------- ------- Epoch151/250 ------- -------
# loss 0.31155, train acc 0.89454, test acc 0.94140
# ------- ------- Epoch152/250 ------- -------
# loss 0.31301, train acc 0.89438, test acc 0.94050
# ------- ------- Epoch153/250 ------- -------
# loss 0.31029, train acc 0.89550, test acc 0.94100
# ------- ------- Epoch154/250 ------- -------
# loss 0.31546, train acc 0.89206, test acc 0.94040
# ------- ------- Epoch155/250 ------- -------
# loss 0.30887, train acc 0.89550, test acc 0.94130
# ------- ------- Epoch156/250 ------- -------
# loss 0.30899, train acc 0.89564, test acc 0.94090
# ------- ------- Epoch157/250 ------- -------
# loss 0.30804, train acc 0.89608, test acc 0.94050
# ------- ------- Epoch158/250 ------- -------
# loss 0.31660, train acc 0.89284, test acc 0.94220
# ------- ------- Epoch159/250 ------- -------
# loss 0.30789, train acc 0.89782, test acc 0.94170
# ------- ------- Epoch160/250 ------- -------
# loss 0.30609, train acc 0.89646, test acc 0.94120
# ------- ------- Epoch161/250 ------- -------
# loss 0.31060, train acc 0.89490, test acc 0.94150
# ------- ------- Epoch162/250 ------- -------
# loss 0.31092, train acc 0.89532, test acc 0.94200
# ------- ------- Epoch163/250 ------- -------
# loss 0.30586, train acc 0.89786, test acc 0.94070
# ------- ------- Epoch164/250 ------- -------
# loss 0.31055, train acc 0.89450, test acc 0.94150
# ------- ------- Epoch165/250 ------- -------
# loss 0.30133, train acc 0.89906, test acc 0.94020
# ------- ------- Epoch166/250 ------- -------
# loss 0.30501, train acc 0.89692, test acc 0.94100
# ------- ------- Epoch167/250 ------- -------
# loss 0.30722, train acc 0.89588, test acc 0.94070
# ------- ------- Epoch168/250 ------- -------
# loss 0.30448, train acc 0.89942, test acc 0.94090
# ------- ------- Epoch169/250 ------- -------
# loss 0.30461, train acc 0.89714, test acc 0.94140
# ------- ------- Epoch170/250 ------- -------
# loss 0.30278, train acc 0.89782, test acc 0.94220
# ------- ------- Epoch171/250 ------- -------
# loss 0.30348, train acc 0.89846, test acc 0.94100
# ------- ------- Epoch172/250 ------- -------
# loss 0.30289, train acc 0.89832, test acc 0.94120
# ------- ------- Epoch173/250 ------- -------
# loss 0.30143, train acc 0.89822, test acc 0.94130
# ------- ------- Epoch174/250 ------- -------
# loss 0.30244, train acc 0.89776, test acc 0.94200
# ------- ------- Epoch175/250 ------- -------
# loss 0.30120, train acc 0.89790, test acc 0.94100
# ------- ------- Epoch176/250 ------- -------
# loss 0.30850, train acc 0.89732, test acc 0.93990
# ------- ------- Epoch177/250 ------- -------
# loss 0.30315, train acc 0.89858, test acc 0.93940
# ------- ------- Epoch178/250 ------- -------
# loss 0.30528, train acc 0.89758, test acc 0.93940
# ------- ------- Epoch179/250 ------- -------
# loss 0.29898, train acc 0.89898, test acc 0.93990
# ------- ------- Epoch180/250 ------- -------
# loss 0.31244, train acc 0.89504, test acc 0.94150
# ------- ------- Epoch181/250 ------- -------
# loss 0.30075, train acc 0.89792, test acc 0.94150
# ------- ------- Epoch182/250 ------- -------
# loss 0.29675, train acc 0.90068, test acc 0.94030
# ------- ------- Epoch183/250 ------- -------
# loss 0.30074, train acc 0.89922, test acc 0.94070
# ------- ------- Epoch184/250 ------- -------
# loss 0.29839, train acc 0.90024, test acc 0.94120
# ------- ------- Epoch185/250 ------- -------
# loss 0.29118, train acc 0.90270, test acc 0.94110
# ------- ------- Epoch186/250 ------- -------
# loss 0.29970, train acc 0.89914, test acc 0.94130
# ------- ------- Epoch187/250 ------- -------
# loss 0.29471, train acc 0.90124, test acc 0.94010
# ------- ------- Epoch188/250 ------- -------
# loss 0.30095, train acc 0.89772, test acc 0.94120
# ------- ------- Epoch189/250 ------- -------
# loss 0.29488, train acc 0.90158, test acc 0.94030
# ------- ------- Epoch190/250 ------- -------
# loss 0.29792, train acc 0.89970, test acc 0.94040
# ------- ------- Epoch191/250 ------- -------
# loss 0.29614, train acc 0.89946, test acc 0.94090
# ------- ------- Epoch192/250 ------- -------
# loss 0.29089, train acc 0.90260, test acc 0.94100
# ------- ------- Epoch193/250 ------- -------
# loss 0.29343, train acc 0.90078, test acc 0.94060
# ------- ------- Epoch194/250 ------- -------
# loss 0.29582, train acc 0.89972, test acc 0.94050
# ------- ------- Epoch195/250 ------- -------
# loss 0.29773, train acc 0.89910, test acc 0.94060
# ------- ------- Epoch196/250 ------- -------
# loss 0.29385, train acc 0.90090, test acc 0.94000
# ------- ------- Epoch197/250 ------- -------
# loss 0.29179, train acc 0.90286, test acc 0.94080
# ------- ------- Epoch198/250 ------- -------
# loss 0.29836, train acc 0.89974, test acc 0.94100
# ------- ------- Epoch199/250 ------- -------
# loss 0.30065, train acc 0.89778, test acc 0.94030
# ------- ------- Epoch200/250 ------- -------
# loss 0.29468, train acc 0.90184, test acc 0.94070
# ------- ------- Epoch201/250 ------- -------
# loss 0.29704, train acc 0.89972, test acc 0.94040
# ------- ------- Epoch202/250 ------- -------
# loss 0.29068, train acc 0.90136, test acc 0.94060
# ------- ------- Epoch203/250 ------- -------
# loss 0.29662, train acc 0.89906, test acc 0.94080
# ------- ------- Epoch204/250 ------- -------
# loss 0.29444, train acc 0.90078, test acc 0.94140
# ------- ------- Epoch205/250 ------- -------
# loss 0.29307, train acc 0.90062, test acc 0.94040
# ------- ------- Epoch206/250 ------- -------
# loss 0.29868, train acc 0.90208, test acc 0.93990
# ------- ------- Epoch207/250 ------- -------
# loss 0.29534, train acc 0.90064, test acc 0.94020
# ------- ------- Epoch208/250 ------- -------
# loss 0.28952, train acc 0.90356, test acc 0.94120
# ------- ------- Epoch209/250 ------- -------
# loss 0.29622, train acc 0.89982, test acc 0.94020
# ------- ------- Epoch210/250 ------- -------
# loss 0.29217, train acc 0.90226, test acc 0.94110
# ------- ------- Epoch211/250 ------- -------
# loss 0.29330, train acc 0.90202, test acc 0.94080
# ------- ------- Epoch212/250 ------- -------
# loss 0.29835, train acc 0.89844, test acc 0.94080
# ------- ------- Epoch213/250 ------- -------
# loss 0.29804, train acc 0.89928, test acc 0.94060
# ------- ------- Epoch214/250 ------- -------
# loss 0.29745, train acc 0.89950, test acc 0.94090
# ------- ------- Epoch215/250 ------- -------
# loss 0.28820, train acc 0.90288, test acc 0.94120
# ------- ------- Epoch216/250 ------- -------
# loss 0.29427, train acc 0.90102, test acc 0.94140
# ------- ------- Epoch217/250 ------- -------
# loss 0.29215, train acc 0.90146, test acc 0.94130
# ------- ------- Epoch218/250 ------- -------
# loss 0.29803, train acc 0.89914, test acc 0.94060
# ------- ------- Epoch219/250 ------- -------
# loss 0.29794, train acc 0.89926, test acc 0.94030
# ------- ------- Epoch220/250 ------- -------
# loss 0.29385, train acc 0.90038, test acc 0.94020
# ------- ------- Epoch221/250 ------- -------
# loss 0.29474, train acc 0.90100, test acc 0.94180
# ------- ------- Epoch222/250 ------- -------
# loss 0.29519, train acc 0.90106, test acc 0.94070
# ------- ------- Epoch223/250 ------- -------
# loss 0.29434, train acc 0.90088, test acc 0.93970
# ------- ------- Epoch224/250 ------- -------
# loss 0.29972, train acc 0.89970, test acc 0.94080
# ------- ------- Epoch225/250 ------- -------
# loss 0.29385, train acc 0.90112, test acc 0.94000
# ------- ------- Epoch226/250 ------- -------
# loss 0.29147, train acc 0.90274, test acc 0.94160
# ------- ------- Epoch227/250 ------- -------
# loss 0.29089, train acc 0.90234, test acc 0.94080
# ------- ------- Epoch228/250 ------- -------
# loss 0.29161, train acc 0.90230, test acc 0.94040
# ------- ------- Epoch229/250 ------- -------
# loss 0.29554, train acc 0.90030, test acc 0.94180
# ------- ------- Epoch230/250 ------- -------
# loss 0.29056, train acc 0.90210, test acc 0.94010
# ------- ------- Epoch231/250 ------- -------
# loss 0.29381, train acc 0.90206, test acc 0.94030
# ------- ------- Epoch232/250 ------- -------
# loss 0.29494, train acc 0.90108, test acc 0.94110
# ------- ------- Epoch233/250 ------- -------
# loss 0.29132, train acc 0.90206, test acc 0.94060
# ------- ------- Epoch234/250 ------- -------
# loss 0.29101, train acc 0.90148, test acc 0.94230
# ------- ------- Epoch235/250 ------- -------
# loss 0.29093, train acc 0.90280, test acc 0.94080
# ------- ------- Epoch236/250 ------- -------
# loss 0.30033, train acc 0.89892, test acc 0.94080
# ------- ------- Epoch237/250 ------- -------
# loss 0.29763, train acc 0.90248, test acc 0.94070
# ------- ------- Epoch238/250 ------- -------
# loss 0.29068, train acc 0.90038, test acc 0.94030
# ------- ------- Epoch239/250 ------- -------
# loss 0.29044, train acc 0.90252, test acc 0.94090
# ------- ------- Epoch240/250 ------- -------
# loss 0.29427, train acc 0.90050, test acc 0.94080
# ------- ------- Epoch241/250 ------- -------
# loss 0.29444, train acc 0.90160, test acc 0.94030
# ------- ------- Epoch242/250 ------- -------
# loss 0.29019, train acc 0.90200, test acc 0.94100
# ------- ------- Epoch243/250 ------- -------
# loss 0.29216, train acc 0.90074, test acc 0.94140
# ------- ------- Epoch244/250 ------- -------
# loss 0.29202, train acc 0.90204, test acc 0.94090
# ------- ------- Epoch245/250 ------- -------
# loss 0.29170, train acc 0.90106, test acc 0.94080
# ------- ------- Epoch246/250 ------- -------
# loss 0.28736, train acc 0.90326, test acc 0.94120
# ------- ------- Epoch247/250 ------- -------
# loss 0.29057, train acc 0.90244, test acc 0.94140
# ------- ------- Epoch248/250 ------- -------
# loss 0.29149, train acc 0.90214, test acc 0.94220
# ------- ------- Epoch249/250 ------- -------
# loss 0.28981, train acc 0.90214, test acc 0.94070
# ------- ------- Epoch250/250 ------- -------
# loss 0.29090, train acc 0.90224, test acc 0.94180

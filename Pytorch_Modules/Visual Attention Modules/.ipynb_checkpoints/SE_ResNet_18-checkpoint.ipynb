# %%
import torch
from torch import nn
from torch.nn import functional as F
from d2l import torch as d2l
import torchvision as tv
import os
import numpy as np

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class SE_Residual(nn.Module):
    def __init__(self, input_channels, num_channels,
                 use_1x1conv=False, strides=1, ratio=16):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, num_channels,
                               kernel_size=3, padding=1, stride=strides)
        self.conv2 = nn.Conv2d(num_channels, num_channels,
                               kernel_size=3, padding=1)
        if use_1x1conv:
            self.conv3 = nn.Conv2d(input_channels, num_channels,
                                   kernel_size=1, stride=strides)
        else:
            self.conv3 = None
        self.bn1 = nn.BatchNorm2d(num_channels)
        self.bn2 = nn.BatchNorm2d(num_channels)

        # SE layers
        self.fc1 = nn.Conv2d(num_channels, num_channels//ratio, kernel_size=1)
        self.fc2 = nn.Conv2d(num_channels//ratio, num_channels, kernel_size=1)



    def forward(self, X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = self.bn2(self.conv2(Y))
        
        # Squeeze
        z = F.avg_pool2d(Y, Y.size(2))
        z = F.relu(self.fc1(z))
        z = F.sigmoid(self.fc2(z))

        # Excitation
        Y = Y * z 

        if self.conv3:
            X = self.conv3(X)

        Y += X
        return F.relu(Y)

# %%
b1 = nn.Sequential(nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
                   nn.BatchNorm2d(64), nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=1, padding=1))

# %%
def se_resnet_block(input_channels, num_channels, num_residuals,
                 first_block=False):
    blk = []
    for i in range(num_residuals):
        if i == 0 and not first_block:
            blk.append(SE_Residual(input_channels, num_channels,
                                use_1x1conv=True, strides=2))
        else:
            blk.append(SE_Residual(num_channels, num_channels))
    return blk

# %%
b2 = nn.Sequential(*se_resnet_block(64, 64, 2, first_block=True))
b3 = nn.Sequential(*se_resnet_block(64, 128, 2))
b4 = nn.Sequential(*se_resnet_block(128, 256, 2))
b5 = nn.Sequential(*se_resnet_block(256, 512, 2))

# %%
se_net18 = nn.Sequential(b1, b2, b3, b4, b5,
                    nn.AdaptiveAvgPool2d((1,1)),
                    nn.Flatten(), nn.Dropout(0.5), nn.Linear(512, 10))

if device == 'cuda':
	se_net18 = torch.nn.DataParallel(se_net18)

# %%
X = torch.rand(size=(1, 3, 32, 32))
for layer in se_net18:
    X = layer(X)
    print(layer.__class__.__name__,'output shape:\t', X.shape)
# Out:
# Sequential output shape:	 torch.Size([1, 64, 32, 32])
# Sequential output shape:	 torch.Size([1, 64, 32, 32])
# Sequential output shape:	 torch.Size([1, 128, 16, 16])
# Sequential output shape:	 torch.Size([1, 256, 8, 8])
# Sequential output shape:	 torch.Size([1, 512, 4, 4])
# AdaptiveAvgPool2d output shape:	 torch.Size([1, 512, 1, 1])
# Flatten output shape:	 torch.Size([1, 512])
# Dropout output shape:	 torch.Size([1, 512])
# Linear output shape:	 torch.Size([1, 10])

# %%
def evaluate_accuracy_gpu(net, data_iter, device=None): 
    if isinstance(net, nn.Module):
        net.eval()  
        if not device:
            device = next(iter(net.parameters())).device
    metric = d2l.Accumulator(2)
    with torch.no_grad():
        for X, y in data_iter:
            if isinstance(X, list):
                X = [x.to(device) for x in X]
            else:
                X = X.to(device)
            y = y.to(device)
            metric.add(d2l.accuracy(net(X), y), y.numel())
    return metric[0] / metric[1]

# %%
def train_net(net, train_iter, test_iter, num_epochs, lr, device):
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            torch.nn.init.kaiming_uniform_(m.weight)
    net.apply(init_weights)
    print('training on', device)
    net.to(device)
    optimizer = torch.optim.SGD(params=net.parameters(),
                          lr=lr,
                          momentum=0.9,
                          weight_decay=0.001)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(
        optimizer, milestones=[50, 100, 150, 200], gamma=0.1)
    loss = nn.CrossEntropyLoss()
    num_batches = len(train_iter)
    for epoch in range(num_epochs):
        metric = d2l.Accumulator(3)
        net.train()
        for i, (X, y) in enumerate(train_iter):
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            optimizer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
        scheduler.step()
        test_acc = evaluate_accuracy_gpu(net, test_iter)
        print(f'------- ------- Epoch{epoch+1}/{num_epochs} ------- -------')
        print(f'loss {train_l:.5f}, train acc {train_acc:.5f}, '
              f'test acc {test_acc:.5f}')

# %%
shape_aug = tv.transforms.RandomResizedCrop(
    (28, 28), scale=(0.1, 1), ratio=(0.5, 2))

color_aug = tv.transforms.ColorJitter(
    brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)

# %%
train_augs = tv.transforms.Compose([
    tv.transforms.RandomCrop(32, padding=4),
    tv.transforms.RandomHorizontalFlip(),
    tv.transforms.ToTensor(), shape_aug, color_aug,
    tv.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

test_augs = tv.transforms.Compose([
    tv.transforms.ToTensor(),
    tv.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# %%
def load_cifar10(is_train, augs, batch_size):
    dataset = tv.datasets.CIFAR10(root="../data", train=is_train,
                                           transform=augs, download=True)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                    shuffle=is_train, num_workers=2)
    return dataloader

# %%
lr, num_epochs, batch_size = 0.01, 250, 128

# %%
train_iter = load_cifar10(True, train_augs, batch_size)
test_iter = load_cifar10(False, test_augs, batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_net(se_net18, train_iter, test_iter, num_epochs, lr, device)
# Out:
# training on cuda
# ------- ------- Epoch1/250 ------- -------
# loss 1.93138, train acc 0.29708, test acc 0.44450
# ------- ------- Epoch2/250 ------- -------
# loss 1.63286, train acc 0.40220, test acc 0.49220
# ------- ------- Epoch3/250 ------- -------
# loss 1.49092, train acc 0.46030, test acc 0.54110
# ------- ------- Epoch4/250 ------- -------
# loss 1.40010, train acc 0.49952, test acc 0.59990
# ------- ------- Epoch5/250 ------- -------
# loss 1.32104, train acc 0.52782, test acc 0.63790
# ------- ------- Epoch6/250 ------- -------
# loss 1.26205, train acc 0.55314, test acc 0.60890
# ------- ------- Epoch7/250 ------- -------
# loss 1.20135, train acc 0.57600, test acc 0.67850
# ------- ------- Epoch8/250 ------- -------
# loss 1.16045, train acc 0.59300, test acc 0.66360
# ------- ------- Epoch9/250 ------- -------
# loss 1.11660, train acc 0.60586, test acc 0.73200
# ------- ------- Epoch10/250 ------- -------
# loss 1.08191, train acc 0.62218, test acc 0.68000
# ------- ------- Epoch11/250 ------- -------
# loss 1.05289, train acc 0.63262, test acc 0.74210
# ------- ------- Epoch12/250 ------- -------
# loss 1.02743, train acc 0.64182, test acc 0.74430
# ------- ------- Epoch13/250 ------- -------
# loss 1.00431, train acc 0.64972, test acc 0.72980
# ------- ------- Epoch14/250 ------- -------
# loss 0.97824, train acc 0.65958, test acc 0.77510
# ------- ------- Epoch15/250 ------- -------
# loss 0.95778, train acc 0.66620, test acc 0.76550
# ------- ------- Epoch16/250 ------- -------
# loss 0.94527, train acc 0.66938, test acc 0.78560
# ------- ------- Epoch17/250 ------- -------
# loss 0.92649, train acc 0.67998, test acc 0.80430
# ------- ------- Epoch18/250 ------- -------
# loss 0.91200, train acc 0.68196, test acc 0.76770
# ------- ------- Epoch19/250 ------- -------
# loss 0.89630, train acc 0.68916, test acc 0.77760
# ------- ------- Epoch20/250 ------- -------
# loss 0.88661, train acc 0.69358, test acc 0.78550
# ------- ------- Epoch21/250 ------- -------
# loss 0.87682, train acc 0.69640, test acc 0.81800
# ------- ------- Epoch22/250 ------- -------
# loss 0.85757, train acc 0.70304, test acc 0.80130
# ------- ------- Epoch23/250 ------- -------
# loss 0.85710, train acc 0.70336, test acc 0.82310
# ------- ------- Epoch24/250 ------- -------
# loss 0.84773, train acc 0.70682, test acc 0.82290
# ------- ------- Epoch25/250 ------- -------
# loss 0.83949, train acc 0.70994, test acc 0.80280
# ------- ------- Epoch26/250 ------- -------
# loss 0.82629, train acc 0.71550, test acc 0.83010
# ------- ------- Epoch27/250 ------- -------
# loss 0.82274, train acc 0.71940, test acc 0.80290
# ------- ------- Epoch28/250 ------- -------
# loss 0.80941, train acc 0.72066, test acc 0.83330
# ------- ------- Epoch29/250 ------- -------
# loss 0.80022, train acc 0.72558, test acc 0.82240
# ------- ------- Epoch30/250 ------- -------
# loss 0.80263, train acc 0.72294, test acc 0.83270
# ------- ------- Epoch31/250 ------- -------
# loss 0.79341, train acc 0.72932, test acc 0.83720
# ------- ------- Epoch32/250 ------- -------
# loss 0.78320, train acc 0.73144, test acc 0.83840
# ------- ------- Epoch33/250 ------- -------
# loss 0.77864, train acc 0.73052, test acc 0.84600
# ------- ------- Epoch34/250 ------- -------
# loss 0.77374, train acc 0.73310, test acc 0.84290
# ------- ------- Epoch35/250 ------- -------
# loss 0.77278, train acc 0.73534, test acc 0.86050
# ------- ------- Epoch36/250 ------- -------
# loss 0.76101, train acc 0.73626, test acc 0.85900
# ------- ------- Epoch37/250 ------- -------
# loss 0.75159, train acc 0.74238, test acc 0.84940
# ------- ------- Epoch38/250 ------- -------
# loss 0.75655, train acc 0.74232, test acc 0.86370
# ------- ------- Epoch39/250 ------- -------
# loss 0.74682, train acc 0.74478, test acc 0.85640
# ------- ------- Epoch40/250 ------- -------
# loss 0.74901, train acc 0.74272, test acc 0.85570
# ------- ------- Epoch41/250 ------- -------
# loss 0.73297, train acc 0.74800, test acc 0.84710
# ------- ------- Epoch42/250 ------- -------
# loss 0.74083, train acc 0.74650, test acc 0.83370
# ------- ------- Epoch43/250 ------- -------
# loss 0.73681, train acc 0.74686, test acc 0.82760
# ------- ------- Epoch44/250 ------- -------
# loss 0.73821, train acc 0.74666, test acc 0.85170
# ------- ------- Epoch45/250 ------- -------
# loss 0.73014, train acc 0.74934, test acc 0.84540
# ------- ------- Epoch46/250 ------- -------
# loss 0.72601, train acc 0.75086, test acc 0.86080
# ------- ------- Epoch47/250 ------- -------
# loss 0.71402, train acc 0.75516, test acc 0.85360
# ------- ------- Epoch48/250 ------- -------
# loss 0.71998, train acc 0.75326, test acc 0.85300
# ------- ------- Epoch49/250 ------- -------
# loss 0.71399, train acc 0.75460, test acc 0.86250
# ------- ------- Epoch50/250 ------- -------
# loss 0.71276, train acc 0.75432, test acc 0.86170
# ------- ------- Epoch51/250 ------- -------
# loss 0.71454, train acc 0.75644, test acc 0.86420
# ------- ------- Epoch52/250 ------- -------
# loss 0.70543, train acc 0.75866, test acc 0.87320
# ------- ------- Epoch53/250 ------- -------
# loss 0.70913, train acc 0.75812, test acc 0.86470
# ------- ------- Epoch54/250 ------- -------
# loss 0.70428, train acc 0.76018, test acc 0.86420
# ------- ------- Epoch55/250 ------- -------
# loss 0.70262, train acc 0.75870, test acc 0.87960
# ------- ------- Epoch56/250 ------- -------
# loss 0.70064, train acc 0.76056, test acc 0.85220
# ------- ------- Epoch57/250 ------- -------
# loss 0.70388, train acc 0.75768, test acc 0.87930
# ------- ------- Epoch58/250 ------- -------
# loss 0.69606, train acc 0.76438, test acc 0.85570
# ------- ------- Epoch59/250 ------- -------
# loss 0.69321, train acc 0.76364, test acc 0.86830
# ------- ------- Epoch60/250 ------- -------
# loss 0.69532, train acc 0.76154, test acc 0.87550
# ------- ------- Epoch61/250 ------- -------
# loss 0.69100, train acc 0.76216, test acc 0.88240
# ------- ------- Epoch62/250 ------- -------
# loss 0.68583, train acc 0.76470, test acc 0.86220
# ------- ------- Epoch63/250 ------- -------
# loss 0.69080, train acc 0.76382, test acc 0.87190
# ------- ------- Epoch64/250 ------- -------
# loss 0.68260, train acc 0.76664, test acc 0.87300
# ------- ------- Epoch65/250 ------- -------
# loss 0.68846, train acc 0.76588, test acc 0.86010
# ------- ------- Epoch66/250 ------- -------
# loss 0.56165, train acc 0.80884, test acc 0.91680
# ------- ------- Epoch67/250 ------- -------
# loss 0.51905, train acc 0.82406, test acc 0.91440
# ------- ------- Epoch68/250 ------- -------
# loss 0.50596, train acc 0.82924, test acc 0.91980
# ------- ------- Epoch69/250 ------- -------
# loss 0.49964, train acc 0.83116, test acc 0.91770
# ------- ------- Epoch70/250 ------- -------
# loss 0.49517, train acc 0.83290, test acc 0.91880
# ------- ------- Epoch71/250 ------- -------
# loss 0.48069, train acc 0.83618, test acc 0.92030
# ------- ------- Epoch72/250 ------- -------
# loss 0.47640, train acc 0.83928, test acc 0.92300
# ------- ------- Epoch73/250 ------- -------
# loss 0.47138, train acc 0.83994, test acc 0.92160
# ------- ------- Epoch74/250 ------- -------
# loss 0.46590, train acc 0.84280, test acc 0.92480
# ------- ------- Epoch75/250 ------- -------
# loss 0.46558, train acc 0.84166, test acc 0.92570
# ------- ------- Epoch76/250 ------- -------
# loss 0.46133, train acc 0.84378, test acc 0.92490
# ------- ------- Epoch77/250 ------- -------
# loss 0.45858, train acc 0.84434, test acc 0.92390
# ------- ------- Epoch78/250 ------- -------
# loss 0.45694, train acc 0.84502, test acc 0.92660
# ------- ------- Epoch79/250 ------- -------
# loss 0.44800, train acc 0.84840, test acc 0.92560
# ------- ------- Epoch80/250 ------- -------
# loss 0.44888, train acc 0.84802, test acc 0.92550
# ------- ------- Epoch81/250 ------- -------
# loss 0.44120, train acc 0.85106, test acc 0.92800
# ------- ------- Epoch82/250 ------- -------
# loss 0.43736, train acc 0.85208, test acc 0.92850
# ------- ------- Epoch83/250 ------- -------
# loss 0.44368, train acc 0.84992, test acc 0.92730
# ------- ------- Epoch84/250 ------- -------
# loss 0.43488, train acc 0.85250, test acc 0.92640
# ------- ------- Epoch85/250 ------- -------
# loss 0.43431, train acc 0.85156, test acc 0.92850
# ------- ------- Epoch86/250 ------- -------
# loss 0.43085, train acc 0.85396, test acc 0.92880
# ------- ------- Epoch87/250 ------- -------
# loss 0.43078, train acc 0.85344, test acc 0.92960
# ------- ------- Epoch88/250 ------- -------
# loss 0.42612, train acc 0.85484, test acc 0.92980
# ------- ------- Epoch89/250 ------- -------
# loss 0.43020, train acc 0.85484, test acc 0.92820
# ------- ------- Epoch90/250 ------- -------
# loss 0.42058, train acc 0.85684, test acc 0.92830
# ------- ------- Epoch91/250 ------- -------
# loss 0.42064, train acc 0.85700, test acc 0.92930
# ------- ------- Epoch92/250 ------- -------
# loss 0.42515, train acc 0.85498, test acc 0.92820
# ------- ------- Epoch93/250 ------- -------
# loss 0.41727, train acc 0.85818, test acc 0.92800
# ------- ------- Epoch94/250 ------- -------
# loss 0.41533, train acc 0.85978, test acc 0.92890
# ------- ------- Epoch95/250 ------- -------
# loss 0.41900, train acc 0.85790, test acc 0.92620
# ------- ------- Epoch96/250 ------- -------
# loss 0.40701, train acc 0.86284, test acc 0.92910
# ------- ------- Epoch97/250 ------- -------
# loss 0.41078, train acc 0.86008, test acc 0.92440
# ------- ------- Epoch98/250 ------- -------
# loss 0.41036, train acc 0.85846, test acc 0.92810
# ------- ------- Epoch99/250 ------- -------
# loss 0.40679, train acc 0.86216, test acc 0.92850
# ------- ------- Epoch100/250 ------- -------
# loss 0.41599, train acc 0.86010, test acc 0.93160
# ------- ------- Epoch101/250 ------- -------
# loss 0.41033, train acc 0.86006, test acc 0.92820
# ------- ------- Epoch102/250 ------- -------
# loss 0.40182, train acc 0.86248, test acc 0.93170
# ------- ------- Epoch103/250 ------- -------
# loss 0.40446, train acc 0.86420, test acc 0.93200
# ------- ------- Epoch104/250 ------- -------
# loss 0.40230, train acc 0.86334, test acc 0.93110
# ------- ------- Epoch105/250 ------- -------
# loss 0.40169, train acc 0.86458, test acc 0.92760
# ------- ------- Epoch106/250 ------- -------
# loss 0.40314, train acc 0.86214, test acc 0.93060
# ------- ------- Epoch107/250 ------- -------
# loss 0.39633, train acc 0.86764, test acc 0.92860
# ------- ------- Epoch108/250 ------- -------
# loss 0.40160, train acc 0.86352, test acc 0.93010
# ------- ------- Epoch109/250 ------- -------
# loss 0.39311, train acc 0.86812, test acc 0.93110
# ------- ------- Epoch110/250 ------- -------
# loss 0.39295, train acc 0.86658, test acc 0.93310
# ------- ------- Epoch111/250 ------- -------
# loss 0.39382, train acc 0.86690, test acc 0.93170
# ------- ------- Epoch112/250 ------- -------
# loss 0.39991, train acc 0.86524, test acc 0.93200
# ------- ------- Epoch113/250 ------- -------
# loss 0.39134, train acc 0.86708, test acc 0.93020
# ------- ------- Epoch114/250 ------- -------
# loss 0.39161, train acc 0.86526, test acc 0.93210
# ------- ------- Epoch115/250 ------- -------
# loss 0.39047, train acc 0.86738, test acc 0.93010
# ------- ------- Epoch116/250 ------- -------
# loss 0.38630, train acc 0.86982, test acc 0.93420
# ------- ------- Epoch117/250 ------- -------
# loss 0.38905, train acc 0.86918, test acc 0.93450
# ------- ------- Epoch118/250 ------- -------
# loss 0.39040, train acc 0.86714, test acc 0.93070
# ------- ------- Epoch119/250 ------- -------
# loss 0.38473, train acc 0.87080, test acc 0.93250
# ------- ------- Epoch120/250 ------- -------
# loss 0.38076, train acc 0.87056, test acc 0.92930
# ------- ------- Epoch121/250 ------- -------
# loss 0.38940, train acc 0.86690, test acc 0.93090
# ------- ------- Epoch122/250 ------- -------
# loss 0.38662, train acc 0.86890, test acc 0.92790
# ------- ------- Epoch123/250 ------- -------
# loss 0.38295, train acc 0.86920, test acc 0.92910
# ------- ------- Epoch124/250 ------- -------
# loss 0.38501, train acc 0.86884, test acc 0.92940
# ------- ------- Epoch125/250 ------- -------
# loss 0.38348, train acc 0.86836, test acc 0.93140
# ------- ------- Epoch126/250 ------- -------
# loss 0.38262, train acc 0.87012, test acc 0.93090
# ------- ------- Epoch127/250 ------- -------
# loss 0.37796, train acc 0.87322, test acc 0.93020
# ------- ------- Epoch128/250 ------- -------
# loss 0.37679, train acc 0.87372, test acc 0.93120
# ------- ------- Epoch129/250 ------- -------
# loss 0.38201, train acc 0.87204, test acc 0.93320
# ------- ------- Epoch130/250 ------- -------
# loss 0.37363, train acc 0.87368, test acc 0.92980
# ------- ------- Epoch131/250 ------- -------
# loss 0.35351, train acc 0.87928, test acc 0.93570
# ------- ------- Epoch132/250 ------- -------
# loss 0.34437, train acc 0.88280, test acc 0.93560
# ------- ------- Epoch133/250 ------- -------
# loss 0.34347, train acc 0.88298, test acc 0.93710
# ------- ------- Epoch134/250 ------- -------
# loss 0.33768, train acc 0.88596, test acc 0.93900
# ------- ------- Epoch135/250 ------- -------
# loss 0.33351, train acc 0.88858, test acc 0.93880
# ------- ------- Epoch136/250 ------- -------
# loss 0.33417, train acc 0.88752, test acc 0.93660
# ------- ------- Epoch137/250 ------- -------
# loss 0.33069, train acc 0.88908, test acc 0.93820
# ------- ------- Epoch138/250 ------- -------
# loss 0.32962, train acc 0.88928, test acc 0.93770
# ------- ------- Epoch139/250 ------- -------
# loss 0.32682, train acc 0.89110, test acc 0.93670
# ------- ------- Epoch140/250 ------- -------
# loss 0.33211, train acc 0.88710, test acc 0.93830
# ------- ------- Epoch141/250 ------- -------
# loss 0.32731, train acc 0.88948, test acc 0.93770
# ------- ------- Epoch142/250 ------- -------
# loss 0.33108, train acc 0.88874, test acc 0.93710
# ------- ------- Epoch143/250 ------- -------
# loss 0.32297, train acc 0.89206, test acc 0.93760
# ------- ------- Epoch144/250 ------- -------
# loss 0.32342, train acc 0.89188, test acc 0.94020
# ------- ------- Epoch145/250 ------- -------
# loss 0.32781, train acc 0.88888, test acc 0.93860
# ------- ------- Epoch146/250 ------- -------
# loss 0.32316, train acc 0.89190, test acc 0.93920
# ------- ------- Epoch147/250 ------- -------
# loss 0.32422, train acc 0.88914, test acc 0.94010
# ------- ------- Epoch148/250 ------- -------
# loss 0.32263, train acc 0.89014, test acc 0.93860
# ------- ------- Epoch149/250 ------- -------
# loss 0.32169, train acc 0.89160, test acc 0.93820
# ------- ------- Epoch150/250 ------- -------
# loss 0.32481, train acc 0.89042, test acc 0.93740
# ------- ------- Epoch151/250 ------- -------
# loss 0.31663, train acc 0.89306, test acc 0.93890
# ------- ------- Epoch152/250 ------- -------
# loss 0.31856, train acc 0.89362, test acc 0.93960
# ------- ------- Epoch153/250 ------- -------
# loss 0.31607, train acc 0.89328, test acc 0.94080
# ------- ------- Epoch154/250 ------- -------
# loss 0.31539, train acc 0.89376, test acc 0.94020
# ------- ------- Epoch155/250 ------- -------
# loss 0.31955, train acc 0.89134, test acc 0.93820
# ------- ------- Epoch156/250 ------- -------
# loss 0.31202, train acc 0.89424, test acc 0.93740
# ------- ------- Epoch157/250 ------- -------
# loss 0.32242, train acc 0.89208, test acc 0.94010
# ------- ------- Epoch158/250 ------- -------
# loss 0.32199, train acc 0.89172, test acc 0.93850
# ------- ------- Epoch159/250 ------- -------
# loss 0.31540, train acc 0.89378, test acc 0.93890
# ------- ------- Epoch160/250 ------- -------
# loss 0.31476, train acc 0.89398, test acc 0.93940
# ------- ------- Epoch161/250 ------- -------
# loss 0.31678, train acc 0.89242, test acc 0.93790
# ------- ------- Epoch162/250 ------- -------
# loss 0.31280, train acc 0.89376, test acc 0.93960
# ------- ------- Epoch163/250 ------- -------
# loss 0.31971, train acc 0.89158, test acc 0.93810
# ------- ------- Epoch164/250 ------- -------
# loss 0.31771, train acc 0.89400, test acc 0.93930
# ------- ------- Epoch165/250 ------- -------
# loss 0.31312, train acc 0.89526, test acc 0.93950
# ------- ------- Epoch166/250 ------- -------
# loss 0.31044, train acc 0.89464, test acc 0.94040
# ------- ------- Epoch167/250 ------- -------
# loss 0.31503, train acc 0.89462, test acc 0.93940
# ------- ------- Epoch168/250 ------- -------
# loss 0.31059, train acc 0.89416, test acc 0.94040
# ------- ------- Epoch169/250 ------- -------
# loss 0.31391, train acc 0.89448, test acc 0.94040
# ------- ------- Epoch170/250 ------- -------
# loss 0.31091, train acc 0.89522, test acc 0.94050
# ------- ------- Epoch171/250 ------- -------
# loss 0.30725, train acc 0.89626, test acc 0.94060
# ------- ------- Epoch172/250 ------- -------
# loss 0.31211, train acc 0.89550, test acc 0.93750
# ------- ------- Epoch173/250 ------- -------
# loss 0.30889, train acc 0.89444, test acc 0.93860
# ------- ------- Epoch174/250 ------- -------
# loss 0.31060, train acc 0.89494, test acc 0.93870
# ------- ------- Epoch175/250 ------- -------
# loss 0.30784, train acc 0.89612, test acc 0.93910
# ------- ------- Epoch176/250 ------- -------
# loss 0.31331, train acc 0.89588, test acc 0.93980
# ------- ------- Epoch177/250 ------- -------
# loss 0.30808, train acc 0.89676, test acc 0.94050
# ------- ------- Epoch178/250 ------- -------
# loss 0.30623, train acc 0.89696, test acc 0.94050
# ------- ------- Epoch179/250 ------- -------
# loss 0.30925, train acc 0.89570, test acc 0.93880
# ------- ------- Epoch180/250 ------- -------
# loss 0.30359, train acc 0.89778, test acc 0.93770
# ------- ------- Epoch181/250 ------- -------
# loss 0.31038, train acc 0.89522, test acc 0.93870
# ------- ------- Epoch182/250 ------- -------
# loss 0.30557, train acc 0.89640, test acc 0.93810
# ------- ------- Epoch183/250 ------- -------
# loss 0.30887, train acc 0.89624, test acc 0.93920
# ------- ------- Epoch184/250 ------- -------
# loss 0.30862, train acc 0.89612, test acc 0.93950
# ------- ------- Epoch185/250 ------- -------
# loss 0.30746, train acc 0.89672, test acc 0.93930
# ------- ------- Epoch186/250 ------- -------
# loss 0.30624, train acc 0.89900, test acc 0.94000
# ------- ------- Epoch187/250 ------- -------
# loss 0.29928, train acc 0.90072, test acc 0.93850
# ------- ------- Epoch188/250 ------- -------
# loss 0.30660, train acc 0.89668, test acc 0.94030
# ------- ------- Epoch189/250 ------- -------
# loss 0.30468, train acc 0.89818, test acc 0.93930
# ------- ------- Epoch190/250 ------- -------
# loss 0.30312, train acc 0.89892, test acc 0.94040
# ------- ------- Epoch191/250 ------- -------
# loss 0.30346, train acc 0.89860, test acc 0.94150
# ------- ------- Epoch192/250 ------- -------
# loss 0.30742, train acc 0.89632, test acc 0.94060
# ------- ------- Epoch193/250 ------- -------
# loss 0.30177, train acc 0.90016, test acc 0.94020
# ------- ------- Epoch194/250 ------- -------
# loss 0.30014, train acc 0.89908, test acc 0.93990
# ------- ------- Epoch195/250 ------- -------
# loss 0.29689, train acc 0.90126, test acc 0.94100
# ------- ------- Epoch196/250 ------- -------
# loss 0.30119, train acc 0.89816, test acc 0.94040
# ------- ------- Epoch197/250 ------- -------
# loss 0.30339, train acc 0.89808, test acc 0.94010
# ------- ------- Epoch198/250 ------- -------
# loss 0.30156, train acc 0.89916, test acc 0.93980
# ------- ------- Epoch199/250 ------- -------
# loss 0.30302, train acc 0.89702, test acc 0.94000
# ------- ------- Epoch200/250 ------- -------
# loss 0.29823, train acc 0.90034, test acc 0.93910
# ------- ------- Epoch201/250 ------- -------
# loss 0.30565, train acc 0.89700, test acc 0.94110
# ------- ------- Epoch202/250 ------- -------
# loss 0.30388, train acc 0.89764, test acc 0.93960
# ------- ------- Epoch203/250 ------- -------
# loss 0.29944, train acc 0.89836, test acc 0.93860
# ------- ------- Epoch204/250 ------- -------
# loss 0.29981, train acc 0.89840, test acc 0.94020
# ------- ------- Epoch205/250 ------- -------
# loss 0.29882, train acc 0.89822, test acc 0.94120
# ------- ------- Epoch206/250 ------- -------
# loss 0.30212, train acc 0.89784, test acc 0.94010
# ------- ------- Epoch207/250 ------- -------
# loss 0.30345, train acc 0.89654, test acc 0.94090
# ------- ------- Epoch208/250 ------- -------
# loss 0.29939, train acc 0.90002, test acc 0.94050
# ------- ------- Epoch209/250 ------- -------
# loss 0.29773, train acc 0.90014, test acc 0.94030
# ------- ------- Epoch210/250 ------- -------
# loss 0.29993, train acc 0.89800, test acc 0.94100
# ------- ------- Epoch211/250 ------- -------
# loss 0.30262, train acc 0.89894, test acc 0.94120
# ------- ------- Epoch212/250 ------- -------
# loss 0.30444, train acc 0.89854, test acc 0.94050
# ------- ------- Epoch213/250 ------- -------
# loss 0.30068, train acc 0.89986, test acc 0.94060
# ------- ------- Epoch214/250 ------- -------
# loss 0.30531, train acc 0.89770, test acc 0.94120
# ------- ------- Epoch215/250 ------- -------
# loss 0.29849, train acc 0.89914, test acc 0.94020
# ------- ------- Epoch216/250 ------- -------
# loss 0.30121, train acc 0.89938, test acc 0.94140
# ------- ------- Epoch217/250 ------- -------
# loss 0.29958, train acc 0.90004, test acc 0.93970
# ------- ------- Epoch218/250 ------- -------
# loss 0.29777, train acc 0.90006, test acc 0.94030
# ------- ------- Epoch219/250 ------- -------
# loss 0.30198, train acc 0.89794, test acc 0.94070
# ------- ------- Epoch220/250 ------- -------
# loss 0.30261, train acc 0.89838, test acc 0.94060
# ------- ------- Epoch221/250 ------- -------
# loss 0.30031, train acc 0.89910, test acc 0.94120
# ------- ------- Epoch222/250 ------- -------
# loss 0.30290, train acc 0.89928, test acc 0.94100
# ------- ------- Epoch223/250 ------- -------
# loss 0.30075, train acc 0.89934, test acc 0.94050
# ------- ------- Epoch224/250 ------- -------
# loss 0.30126, train acc 0.89930, test acc 0.94110
# ------- ------- Epoch225/250 ------- -------
# loss 0.30256, train acc 0.89892, test acc 0.94130
# ------- ------- Epoch226/250 ------- -------
# loss 0.30787, train acc 0.89678, test acc 0.93970
# ------- ------- Epoch227/250 ------- -------
# loss 0.30604, train acc 0.89818, test acc 0.94090
# ------- ------- Epoch228/250 ------- -------
# loss 0.30027, train acc 0.90000, test acc 0.94000
# ------- ------- Epoch229/250 ------- -------
# loss 0.30626, train acc 0.89766, test acc 0.94030
# ------- ------- Epoch230/250 ------- -------
# loss 0.30063, train acc 0.89994, test acc 0.94100
# ------- ------- Epoch231/250 ------- -------
# loss 0.30180, train acc 0.89916, test acc 0.94190
# ------- ------- Epoch232/250 ------- -------
# loss 0.30110, train acc 0.89926, test acc 0.94100
# ------- ------- Epoch233/250 ------- -------
# loss 0.29995, train acc 0.89900, test acc 0.94110
# ------- ------- Epoch234/250 ------- -------
# loss 0.30655, train acc 0.89774, test acc 0.94080
# ------- ------- Epoch235/250 ------- -------
# loss 0.30072, train acc 0.89972, test acc 0.94090
# ------- ------- Epoch236/250 ------- -------
# loss 0.29855, train acc 0.89900, test acc 0.94120
# ------- ------- Epoch237/250 ------- -------
# loss 0.30202, train acc 0.89832, test acc 0.93970
# ------- ------- Epoch238/250 ------- -------
# loss 0.30184, train acc 0.89858, test acc 0.94050
# ------- ------- Epoch239/250 ------- -------
# loss 0.29415, train acc 0.89970, test acc 0.93980
# ------- ------- Epoch240/250 ------- -------
# loss 0.30223, train acc 0.89806, test acc 0.94100
# ------- ------- Epoch241/250 ------- -------
# loss 0.29896, train acc 0.89854, test acc 0.94020
# ------- ------- Epoch242/250 ------- -------
# loss 0.30056, train acc 0.90016, test acc 0.94090
# ------- ------- Epoch243/250 ------- -------
# loss 0.31000, train acc 0.89630, test acc 0.94130
# ------- ------- Epoch244/250 ------- -------
# loss 0.30257, train acc 0.89926, test acc 0.93940
# ------- ------- Epoch245/250 ------- -------
# loss 0.30080, train acc 0.89834, test acc 0.94110
# ------- ------- Epoch246/250 ------- -------
# loss 0.29900, train acc 0.89876, test acc 0.94100
# ------- ------- Epoch247/250 ------- -------
# loss 0.31041, train acc 0.89634, test acc 0.94120
# ------- ------- Epoch248/250 ------- -------
# loss 0.30195, train acc 0.89852, test acc 0.93990
# ------- ------- Epoch249/250 ------- -------
# loss 0.30822, train acc 0.89770, test acc 0.94100

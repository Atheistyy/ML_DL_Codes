# %%
import torch
from torch import nn
from torch.nn import functional as F
from d2l import torch as d2l
import torchvision as tv
import os
import numpy as np

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class ChannelAttentionModule(nn.Module):
    def __init__(self, num_channels, ratio=16):
        super(ChannelAttentionModule, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)
 
        self.shared_MLP = nn.Sequential(
            nn.Conv2d(num_channels, num_channels // ratio, 1, bias=False),
            nn.ReLU(),
            nn.Conv2d(num_channels // ratio, num_channels, 1, bias=False)
        )
        self.sigmoid = nn.Sigmoid()
 
    def forward(self, X):
        avgout = self.shared_MLP(self.avg_pool(X))
        maxout = self.shared_MLP(self.max_pool(X))
        return self.sigmoid(avgout + maxout)
 
class SpatialAttentionModule(nn.Module):
    def __init__(self):
        super(SpatialAttentionModule, self).__init__()
        self.conv2d = nn.Conv2d(in_channels=2, out_channels=1, kernel_size=3, stride=1, padding=1)
        self.sigmoid = nn.Sigmoid()
 
    def forward(self, X):
        avgout = torch.mean(X, dim=1, keepdim=True)
        maxout, _ = torch.max(X, dim=1, keepdim=True)
        Y = torch.cat([avgout, maxout], dim=1)
        Y = self.sigmoid(self.conv2d(Y))
        return Y
 
class CBAM(nn.Module):
    def __init__(self, num_channels):
        super(CBAM, self).__init__()
        self.channel_attention = ChannelAttentionModule(num_channels)
        self.spatial_attention = SpatialAttentionModule()
 
    def forward(self, X):
        Y = self.channel_attention(X) * X
        Y = self.spatial_attention(Y) * Y
        
        return Y

# %%
class Residual(nn.Module):
    def __init__(self, input_channels, num_channels,
                 use_1x1conv=False, strides=1, ratio=16):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, num_channels//4,
                               kernel_size=1, padding=0)
        self.conv2 = nn.Conv2d(num_channels//4, num_channels//4,
                               kernel_size=3, padding=1,stride=strides)
        self.conv3 = nn.Conv2d(num_channels//4, num_channels,
                               kernel_size=1, padding=0)
        
        if use_1x1conv:
            self.conv4 = nn.Conv2d(input_channels, num_channels,
                                   kernel_size=1, stride=strides)
        else:
            self.conv4 = None
            
        self.bn1 = nn.BatchNorm2d(num_channels//4)
        self.bn2 = nn.BatchNorm2d(num_channels//4)
        self.bn3 = nn.BatchNorm2d(num_channels)
        
        self.cbam = CBAM(num_channels)

    def forward(self, X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = F.relu(self.bn2(self.conv2(Y)))
        Y = self.bn3(self.conv3(Y))
        
        Y = self.cbam(Y)
        
        if self.conv4:
            X = self.conv4(X)
            
        Y += X
        return F.relu(Y)

# %%
b1 = nn.Sequential(nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
                   nn.BatchNorm2d(64), nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=1, padding=1))

# %%
def resnet_block(input_channels, num_channels, num_residuals,
                 first_block=False):
    blk = []
    for i in range(num_residuals):
        if i == 0 and not first_block:
            blk.append(Residual(input_channels, num_channels,
                                use_1x1conv=True, strides=2))
        elif i == 0 and first_block:
            blk.append(Residual(input_channels, num_channels,
                                use_1x1conv=True))
        else:
            blk.append(Residual(num_channels, num_channels))
    return blk

# %%
b2 = nn.Sequential(*resnet_block(64, 256, 3, first_block=True))
b3 = nn.Sequential(*resnet_block(256, 512, 4))
b4 = nn.Sequential(*resnet_block(512, 1024, 6))
b5 = nn.Sequential(*resnet_block(1024, 2048, 3))

# %%
net = nn.Sequential(b1, b2, b3, b4, b5,
                    nn.AdaptiveAvgPool2d((1,1)),
                    nn.Flatten(), nn.Dropout(0.25), nn.Linear(2048, 10))

if device == 'cuda':
	net = torch.nn.DataParallel(net)

# %%
X = torch.rand(size=(1, 3, 32, 32))
for layer in net:
    X = layer(X)
    print(layer.__class__.__name__,'output shape:\t', X.shape)
# Out:
# Sequential output shape:	 torch.Size([1, 64, 32, 32])
# Sequential output shape:	 torch.Size([1, 256, 32, 32])
# Sequential output shape:	 torch.Size([1, 512, 16, 16])
# Sequential output shape:	 torch.Size([1, 1024, 8, 8])
# Sequential output shape:	 torch.Size([1, 2048, 4, 4])
# AdaptiveAvgPool2d output shape:	 torch.Size([1, 2048, 1, 1])
# Flatten output shape:	 torch.Size([1, 2048])
# Dropout output shape:	 torch.Size([1, 2048])
# Linear output shape:	 torch.Size([1, 10])

# %%
def evaluate_accuracy_gpu(net, data_iter, device=None): 
    if isinstance(net, nn.Module):
        net.eval()  
        if not device:
            device = next(iter(net.parameters())).device
    metric = d2l.Accumulator(2)
    with torch.no_grad():
        for X, y in data_iter:
            if isinstance(X, list):
                X = [x.to(device) for x in X]
            else:
                X = X.to(device)
            y = y.to(device)
            metric.add(d2l.accuracy(net(X), y), y.numel())
    return metric[0] / metric[1]

# %%
def train_net(net, train_iter, test_iter, num_epochs, lr, device):
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            torch.nn.init.kaiming_uniform_(m.weight)
    net.apply(init_weights)
    print('training on', device)
    net.to(device)
    optimizer = torch.optim.SGD(params=net.parameters(),
                          lr=lr,
                          momentum=0.9,
                          weight_decay=0.001)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(
        optimizer, milestones=[65, 130, 195], gamma=0.1)
    loss = nn.CrossEntropyLoss()
    num_batches = len(train_iter)
    for epoch in range(num_epochs):
        metric = d2l.Accumulator(3)
        net.train()
        for i, (X, y) in enumerate(train_iter):
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            optimizer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
        scheduler.step()
        test_acc = evaluate_accuracy_gpu(net, test_iter)
        print(f'------- ------- Epoch{epoch+1}/{num_epochs} ------- -------')
        print(f'loss {train_l:.5f}, train acc {train_acc:.5f}, '
          f'test acc {test_acc:.5f}')

# %%
shape_aug = tv.transforms.RandomResizedCrop(
    (28, 28), scale=(0.1, 1), ratio=(0.5, 2))

# %%
train_augs = tv.transforms.Compose([
    tv.transforms.RandomCrop(32, padding=4),
    tv.transforms.RandomHorizontalFlip(),
    tv.transforms.ToTensor(), shape_aug,
    tv.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

test_augs = tv.transforms.Compose([
    tv.transforms.ToTensor(), 
    tv.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# %%
def load_cifar10(is_train, augs, batch_size):
    dataset = tv.datasets.CIFAR10(root="../data", train=is_train,
                                           transform=augs, download=True)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                    shuffle=is_train, num_workers=4)
    return dataloader

# %%
lr, num_epochs, batch_size = 0.01, 250, 128

# %%
train_iter = load_cifar10(True, train_augs, batch_size)
test_iter = load_cifar10(False, test_augs, batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_net(net, train_iter, test_iter, num_epochs, lr, device)
# Out:
# training on cuda
# ------- ------- Epoch1/250 ------- -------
# loss 2.03381, train acc 0.27808, test acc 0.34690
# ------- ------- Epoch2/250 ------- -------
# loss 1.71937, train acc 0.36576, test acc 0.44240
# ------- ------- Epoch3/250 ------- -------
# loss 1.60413, train acc 0.41446, test acc 0.48390
# ------- ------- Epoch4/250 ------- -------
# loss 1.52555, train acc 0.44718, test acc 0.47640
# ------- ------- Epoch5/250 ------- -------
# loss 1.44347, train acc 0.47720, test acc 0.47350
# ------- ------- Epoch6/250 ------- -------
# loss 1.38413, train acc 0.49992, test acc 0.54440
# ------- ------- Epoch7/250 ------- -------
# loss 1.32658, train acc 0.52346, test acc 0.57790
# ------- ------- Epoch8/250 ------- -------
# loss 1.27398, train acc 0.54366, test acc 0.54740
# ------- ------- Epoch9/250 ------- -------
# loss 1.23020, train acc 0.56294, test acc 0.64000
# ------- ------- Epoch10/250 ------- -------
# loss 1.18499, train acc 0.57792, test acc 0.63330
# ------- ------- Epoch11/250 ------- -------
# loss 1.14989, train acc 0.59196, test acc 0.61750
# ------- ------- Epoch12/250 ------- -------
# loss 1.11442, train acc 0.60648, test acc 0.67980
# ------- ------- Epoch13/250 ------- -------
# loss 1.07826, train acc 0.61782, test acc 0.72950
# ------- ------- Epoch14/250 ------- -------
# loss 1.04778, train acc 0.62874, test acc 0.74130
# ------- ------- Epoch15/250 ------- -------
# loss 1.02341, train acc 0.63868, test acc 0.71100
# ------- ------- Epoch16/250 ------- -------
# loss 1.00072, train acc 0.64902, test acc 0.72200
# ------- ------- Epoch17/250 ------- -------
# loss 0.97513, train acc 0.65942, test acc 0.76290
# ------- ------- Epoch18/250 ------- -------
# loss 0.95070, train acc 0.66540, test acc 0.72680
# ------- ------- Epoch19/250 ------- -------
# loss 0.93863, train acc 0.67390, test acc 0.77200
# ------- ------- Epoch20/250 ------- -------
# loss 0.92110, train acc 0.67698, test acc 0.74380
# ------- ------- Epoch21/250 ------- -------
# loss 0.91201, train acc 0.68218, test acc 0.75700
# ------- ------- Epoch22/250 ------- -------
# loss 0.88524, train acc 0.68992, test acc 0.79230
# ------- ------- Epoch23/250 ------- -------
# loss 0.87685, train acc 0.69448, test acc 0.80740
# ------- ------- Epoch24/250 ------- -------
# loss 0.86898, train acc 0.69640, test acc 0.78110
# ------- ------- Epoch25/250 ------- -------
# loss 0.85843, train acc 0.70250, test acc 0.78580
# ------- ------- Epoch26/250 ------- -------
# loss 0.84775, train acc 0.70346, test acc 0.81240
# ------- ------- Epoch27/250 ------- -------
# loss 0.84063, train acc 0.70524, test acc 0.81150
# ------- ------- Epoch28/250 ------- -------
# loss 0.82357, train acc 0.71284, test acc 0.81260
# ------- ------- Epoch29/250 ------- -------
# loss 0.82199, train acc 0.71410, test acc 0.82190
# ------- ------- Epoch30/250 ------- -------
# loss 0.81265, train acc 0.71700, test acc 0.82080
# ------- ------- Epoch31/250 ------- -------
# loss 0.81104, train acc 0.71974, test acc 0.81320
# ------- ------- Epoch32/250 ------- -------
# loss 0.79863, train acc 0.72086, test acc 0.81750
# ------- ------- Epoch33/250 ------- -------
# loss 0.78541, train acc 0.72750, test acc 0.83400
# ------- ------- Epoch34/250 ------- -------
# loss 0.78124, train acc 0.72866, test acc 0.83140
# ------- ------- Epoch35/250 ------- -------
# loss 0.77951, train acc 0.72872, test acc 0.84980
# ------- ------- Epoch36/250 ------- -------
# loss 0.77410, train acc 0.73128, test acc 0.83120
# ------- ------- Epoch37/250 ------- -------
# loss 0.77395, train acc 0.73246, test acc 0.80980
# ------- ------- Epoch38/250 ------- -------
# loss 0.75646, train acc 0.73894, test acc 0.82640
# ------- ------- Epoch39/250 ------- -------
# loss 0.76082, train acc 0.73534, test acc 0.83690
# ------- ------- Epoch40/250 ------- -------
# loss 0.75403, train acc 0.73946, test acc 0.82740
# ------- ------- Epoch41/250 ------- -------
# loss 0.74661, train acc 0.74182, test acc 0.80920
# ------- ------- Epoch42/250 ------- -------
# loss 0.74916, train acc 0.73966, test acc 0.84460
# ------- ------- Epoch43/250 ------- -------
# loss 0.73783, train acc 0.74446, test acc 0.85720
# ------- ------- Epoch44/250 ------- -------
# loss 0.74160, train acc 0.74212, test acc 0.84940
# ------- ------- Epoch45/250 ------- -------
# loss 0.73998, train acc 0.74422, test acc 0.85700
# ------- ------- Epoch46/250 ------- -------
# loss 0.73187, train acc 0.74584, test acc 0.85660
# ------- ------- Epoch47/250 ------- -------
# loss 0.72382, train acc 0.74956, test acc 0.85540
# ------- ------- Epoch48/250 ------- -------
# loss 0.72571, train acc 0.74892, test acc 0.86660
# ------- ------- Epoch49/250 ------- -------
# loss 0.71910, train acc 0.75134, test acc 0.84450
# ------- ------- Epoch50/250 ------- -------
# loss 0.71712, train acc 0.74870, test acc 0.86380
# ------- ------- Epoch51/250 ------- -------
# loss 0.71789, train acc 0.75268, test acc 0.84250
# ------- ------- Epoch52/250 ------- -------
# loss 0.71399, train acc 0.75346, test acc 0.83870
# ------- ------- Epoch53/250 ------- -------
# loss 0.70722, train acc 0.75504, test acc 0.86690
# ------- ------- Epoch54/250 ------- -------
# loss 0.70924, train acc 0.75322, test acc 0.86900
# ------- ------- Epoch55/250 ------- -------
# loss 0.69781, train acc 0.75942, test acc 0.84730
# ------- ------- Epoch56/250 ------- -------
# loss 0.70444, train acc 0.75526, test acc 0.86640
# ------- ------- Epoch57/250 ------- -------
# loss 0.69577, train acc 0.75884, test acc 0.86490
# ------- ------- Epoch58/250 ------- -------
# loss 0.70522, train acc 0.75446, test acc 0.87650
# ------- ------- Epoch59/250 ------- -------
# loss 0.68552, train acc 0.76312, test acc 0.87510
# ------- ------- Epoch60/250 ------- -------
# loss 0.69226, train acc 0.76130, test acc 0.84090
# ------- ------- Epoch61/250 ------- -------
# loss 0.68968, train acc 0.76002, test acc 0.86860
# ------- ------- Epoch62/250 ------- -------
# loss 0.69542, train acc 0.76082, test acc 0.86930
# ------- ------- Epoch63/250 ------- -------
# loss 0.69098, train acc 0.76174, test acc 0.87450
# ------- ------- Epoch64/250 ------- -------
# loss 0.68734, train acc 0.76536, test acc 0.86540
# ------- ------- Epoch65/250 ------- -------
# loss 0.67865, train acc 0.76526, test acc 0.86570
# ------- ------- Epoch66/250 ------- -------
# loss 0.55105, train acc 0.81044, test acc 0.91950
# ------- ------- Epoch67/250 ------- -------
# loss 0.50667, train acc 0.82696, test acc 0.92290
# ------- ------- Epoch68/250 ------- -------
# loss 0.48620, train acc 0.83522, test acc 0.92850
# ------- ------- Epoch69/250 ------- -------
# loss 0.47896, train acc 0.83622, test acc 0.92550
# ------- ------- Epoch70/250 ------- -------
# loss 0.46801, train acc 0.84090, test acc 0.92530
# ------- ------- Epoch71/250 ------- -------
# loss 0.46430, train acc 0.84062, test acc 0.93020
# ------- ------- Epoch72/250 ------- -------
# loss 0.45566, train acc 0.84406, test acc 0.93090
# ------- ------- Epoch73/250 ------- -------
# loss 0.45078, train acc 0.84524, test acc 0.93070
# ------- ------- Epoch74/250 ------- -------
# loss 0.44572, train acc 0.84672, test acc 0.92940
# ------- ------- Epoch75/250 ------- -------
# loss 0.44727, train acc 0.84722, test acc 0.93180
# ------- ------- Epoch76/250 ------- -------
# loss 0.44284, train acc 0.84976, test acc 0.93210
# ------- ------- Epoch77/250 ------- -------
# loss 0.43248, train acc 0.85122, test acc 0.93360
# ------- ------- Epoch78/250 ------- -------
# loss 0.43874, train acc 0.84908, test acc 0.93110
# ------- ------- Epoch79/250 ------- -------
# loss 0.42750, train acc 0.85418, test acc 0.93470
# ------- ------- Epoch80/250 ------- -------
# loss 0.41811, train acc 0.85600, test acc 0.93310
# ------- ------- Epoch81/250 ------- -------
# loss 0.42584, train acc 0.85338, test acc 0.93480
# ------- ------- Epoch82/250 ------- -------
# loss 0.41685, train acc 0.85620, test acc 0.93180
# ------- ------- Epoch83/250 ------- -------
# loss 0.41865, train acc 0.85548, test acc 0.93220
# ------- ------- Epoch84/250 ------- -------
# loss 0.41430, train acc 0.85766, test acc 0.93250
# ------- ------- Epoch85/250 ------- -------
# loss 0.41962, train acc 0.85678, test acc 0.93620
# ------- ------- Epoch86/250 ------- -------
# loss 0.41024, train acc 0.85974, test acc 0.93390
# ------- ------- Epoch87/250 ------- -------
# loss 0.40113, train acc 0.86130, test acc 0.93090
# ------- ------- Epoch88/250 ------- -------
# loss 0.41231, train acc 0.85738, test acc 0.93380
# ------- ------- Epoch89/250 ------- -------
# loss 0.40063, train acc 0.86390, test acc 0.93760
# ------- ------- Epoch90/250 ------- -------
# loss 0.40162, train acc 0.86220, test acc 0.93650
# ------- ------- Epoch91/250 ------- -------
# loss 0.39875, train acc 0.86416, test acc 0.93710
# ------- ------- Epoch92/250 ------- -------
# loss 0.39568, train acc 0.86392, test acc 0.93740
# ------- ------- Epoch93/250 ------- -------
# loss 0.39813, train acc 0.86176, test acc 0.93260
# ------- ------- Epoch94/250 ------- -------
# loss 0.39299, train acc 0.86622, test acc 0.93970
# ------- ------- Epoch95/250 ------- -------
# loss 0.39208, train acc 0.86486, test acc 0.93620
# ------- ------- Epoch96/250 ------- -------
# loss 0.38875, train acc 0.86552, test acc 0.93670
# ------- ------- Epoch97/250 ------- -------
# loss 0.38903, train acc 0.86694, test acc 0.93610
# ------- ------- Epoch98/250 ------- -------
# loss 0.39216, train acc 0.86508, test acc 0.93540
# ------- ------- Epoch99/250 ------- -------
# loss 0.38349, train acc 0.86762, test acc 0.93810
# ------- ------- Epoch100/250 ------- -------
# loss 0.38165, train acc 0.86992, test acc 0.93750
# ------- ------- Epoch101/250 ------- -------
# loss 0.38200, train acc 0.86930, test acc 0.93540
# ------- ------- Epoch102/250 ------- -------
# loss 0.38057, train acc 0.86810, test acc 0.93720
# ------- ------- Epoch103/250 ------- -------
# loss 0.37507, train acc 0.87184, test acc 0.93840
# ------- ------- Epoch104/250 ------- -------
# loss 0.37709, train acc 0.87126, test acc 0.93910
# ------- ------- Epoch105/250 ------- -------
# loss 0.37450, train acc 0.87170, test acc 0.93380
# ------- ------- Epoch106/250 ------- -------
# loss 0.37354, train acc 0.87324, test acc 0.93670
# ------- ------- Epoch107/250 ------- -------
# loss 0.37343, train acc 0.87162, test acc 0.93790
# ------- ------- Epoch108/250 ------- -------
# loss 0.37455, train acc 0.87178, test acc 0.93280
# ------- ------- Epoch109/250 ------- -------
# loss 0.37357, train acc 0.87234, test acc 0.93510
# ------- ------- Epoch110/250 ------- -------
# loss 0.37349, train acc 0.87136, test acc 0.93140
# ------- ------- Epoch111/250 ------- -------
# loss 0.37061, train acc 0.87406, test acc 0.93940
# ------- ------- Epoch112/250 ------- -------
# loss 0.36638, train acc 0.87422, test acc 0.93670
# ------- ------- Epoch113/250 ------- -------
# loss 0.36609, train acc 0.87476, test acc 0.93170
# ------- ------- Epoch114/250 ------- -------
# loss 0.37186, train acc 0.87238, test acc 0.93680
# ------- ------- Epoch115/250 ------- -------
# loss 0.36981, train acc 0.87344, test acc 0.93560
# ------- ------- Epoch116/250 ------- -------
# loss 0.36483, train acc 0.87558, test acc 0.93690
# ------- ------- Epoch117/250 ------- -------
# loss 0.36744, train acc 0.87464, test acc 0.93490
# ------- ------- Epoch118/250 ------- -------
# loss 0.36466, train acc 0.87628, test acc 0.93770
# ------- ------- Epoch119/250 ------- -------
# loss 0.36033, train acc 0.87728, test acc 0.93650
# ------- ------- Epoch120/250 ------- -------
# loss 0.36182, train acc 0.87558, test acc 0.93750
# ------- ------- Epoch121/250 ------- -------
# loss 0.36008, train acc 0.87562, test acc 0.93800
# ------- ------- Epoch122/250 ------- -------
# loss 0.35887, train acc 0.87676, test acc 0.93320
# ------- ------- Epoch123/250 ------- -------
# loss 0.35960, train acc 0.87712, test acc 0.93760
# ------- ------- Epoch124/250 ------- -------
# loss 0.35942, train acc 0.87648, test acc 0.93920
# ------- ------- Epoch125/250 ------- -------
# loss 0.35975, train acc 0.87682, test acc 0.93370
# ------- ------- Epoch126/250 ------- -------
# loss 0.35896, train acc 0.87618, test acc 0.93860
# ------- ------- Epoch127/250 ------- -------
# loss 0.35283, train acc 0.87892, test acc 0.93630
# ------- ------- Epoch128/250 ------- -------
# loss 0.35597, train acc 0.87732, test acc 0.93620
# ------- ------- Epoch129/250 ------- -------
# loss 0.35757, train acc 0.87682, test acc 0.93540
# ------- ------- Epoch130/250 ------- -------
# loss 0.35483, train acc 0.87798, test acc 0.93770
# ------- ------- Epoch131/250 ------- -------
# loss 0.32494, train acc 0.88806, test acc 0.94380
# ------- ------- Epoch132/250 ------- -------
# loss 0.31075, train acc 0.89430, test acc 0.94470
# ------- ------- Epoch133/250 ------- -------
# loss 0.30992, train acc 0.89396, test acc 0.94450
# ------- ------- Epoch134/250 ------- -------
# loss 0.30884, train acc 0.89432, test acc 0.94620
# ------- ------- Epoch135/250 ------- -------
# loss 0.29940, train acc 0.89712, test acc 0.94620
# ------- ------- Epoch136/250 ------- -------
# loss 0.29651, train acc 0.89936, test acc 0.94650
# ------- ------- Epoch137/250 ------- -------
# loss 0.29883, train acc 0.89786, test acc 0.94570
# ------- ------- Epoch138/250 ------- -------
# loss 0.29357, train acc 0.90042, test acc 0.94560
# ------- ------- Epoch139/250 ------- -------
# loss 0.30343, train acc 0.89594, test acc 0.94760
# ------- ------- Epoch140/250 ------- -------
# loss 0.28868, train acc 0.90286, test acc 0.94630
# ------- ------- Epoch141/250 ------- -------
# loss 0.28829, train acc 0.90270, test acc 0.94750
# ------- ------- Epoch142/250 ------- -------
# loss 0.28934, train acc 0.90214, test acc 0.94600
# ------- ------- Epoch143/250 ------- -------
# loss 0.29157, train acc 0.90116, test acc 0.94640
# ------- ------- Epoch144/250 ------- -------
# loss 0.28661, train acc 0.90296, test acc 0.94770
# ------- ------- Epoch145/250 ------- -------
# loss 0.28936, train acc 0.90154, test acc 0.94750
# ------- ------- Epoch146/250 ------- -------
# loss 0.28980, train acc 0.90174, test acc 0.94880
# ------- ------- Epoch147/250 ------- -------
# loss 0.28288, train acc 0.90404, test acc 0.94850
# ------- ------- Epoch148/250 ------- -------
# loss 0.28574, train acc 0.90270, test acc 0.94930
# ------- ------- Epoch149/250 ------- -------
# loss 0.28515, train acc 0.90300, test acc 0.94860
# ------- ------- Epoch150/250 ------- -------
# loss 0.28726, train acc 0.90286, test acc 0.94690
# ------- ------- Epoch151/250 ------- -------
# loss 0.28935, train acc 0.90186, test acc 0.94890
# ------- ------- Epoch152/250 ------- -------
# loss 0.28310, train acc 0.90314, test acc 0.94740
# ------- ------- Epoch153/250 ------- -------
# loss 0.28298, train acc 0.90430, test acc 0.94880
# ------- ------- Epoch154/250 ------- -------
# loss 0.28010, train acc 0.90584, test acc 0.94690
# ------- ------- Epoch155/250 ------- -------
# loss 0.27854, train acc 0.90644, test acc 0.94800
# ------- ------- Epoch156/250 ------- -------
# loss 0.27801, train acc 0.90540, test acc 0.94870
# ------- ------- Epoch157/250 ------- -------
# loss 0.28642, train acc 0.90312, test acc 0.94750
# ------- ------- Epoch158/250 ------- -------
# loss 0.27738, train acc 0.90654, test acc 0.94770
# ------- ------- Epoch159/250 ------- -------
# loss 0.27927, train acc 0.90536, test acc 0.94780
# ------- ------- Epoch160/250 ------- -------
# loss 0.28355, train acc 0.90456, test acc 0.94800
# ------- ------- Epoch161/250 ------- -------
# loss 0.27756, train acc 0.90608, test acc 0.94830
# ------- ------- Epoch162/250 ------- -------
# loss 0.27560, train acc 0.90634, test acc 0.94950
# ------- ------- Epoch163/250 ------- -------
# loss 0.27711, train acc 0.90578, test acc 0.94980
# ------- ------- Epoch164/250 ------- -------
# loss 0.27497, train acc 0.90694, test acc 0.94900
# ------- ------- Epoch165/250 ------- -------
# loss 0.27376, train acc 0.90714, test acc 0.94680
# ------- ------- Epoch166/250 ------- -------
# loss 0.27869, train acc 0.90540, test acc 0.94660
# ------- ------- Epoch167/250 ------- -------
# loss 0.26732, train acc 0.90886, test acc 0.94780
# ------- ------- Epoch168/250 ------- -------
# loss 0.27092, train acc 0.90852, test acc 0.94880
# ------- ------- Epoch169/250 ------- -------
# loss 0.27886, train acc 0.90588, test acc 0.94770
# ------- ------- Epoch170/250 ------- -------
# loss 0.27293, train acc 0.90824, test acc 0.94870
# ------- ------- Epoch171/250 ------- -------
# loss 0.27141, train acc 0.90908, test acc 0.94990
# ------- ------- Epoch172/250 ------- -------
# loss 0.26801, train acc 0.91030, test acc 0.94750
# ------- ------- Epoch173/250 ------- -------
# loss 0.27231, train acc 0.90804, test acc 0.94900
# ------- ------- Epoch174/250 ------- -------
# loss 0.27196, train acc 0.90820, test acc 0.94880
# ------- ------- Epoch175/250 ------- -------
# loss 0.26900, train acc 0.90828, test acc 0.94740
# ------- ------- Epoch176/250 ------- -------
# loss 0.27237, train acc 0.90704, test acc 0.94910
# ------- ------- Epoch177/250 ------- -------
# loss 0.27108, train acc 0.90842, test acc 0.94890
# ------- ------- Epoch178/250 ------- -------
# loss 0.26940, train acc 0.90810, test acc 0.94840
# ------- ------- Epoch179/250 ------- -------
# loss 0.26740, train acc 0.91016, test acc 0.94750
# ------- ------- Epoch180/250 ------- -------
# loss 0.27218, train acc 0.90796, test acc 0.94870
# ------- ------- Epoch181/250 ------- -------
# loss 0.26761, train acc 0.91014, test acc 0.94850
# ------- ------- Epoch182/250 ------- -------
# loss 0.26784, train acc 0.90860, test acc 0.94820
# ------- ------- Epoch183/250 ------- -------
# loss 0.27394, train acc 0.90658, test acc 0.94700
# ------- ------- Epoch184/250 ------- -------
# loss 0.26958, train acc 0.90760, test acc 0.94810
# ------- ------- Epoch185/250 ------- -------
# loss 0.27046, train acc 0.90876, test acc 0.94730
# ------- ------- Epoch186/250 ------- -------
# loss 0.27296, train acc 0.90660, test acc 0.94770
# ------- ------- Epoch187/250 ------- -------
# loss 0.26740, train acc 0.90978, test acc 0.94700
# ------- ------- Epoch188/250 ------- -------
# loss 0.26564, train acc 0.91034, test acc 0.94710
# ------- ------- Epoch189/250 ------- -------
# loss 0.27043, train acc 0.90800, test acc 0.94790
# ------- ------- Epoch190/250 ------- -------
# loss 0.27045, train acc 0.90778, test acc 0.94660
# ------- ------- Epoch191/250 ------- -------
# loss 0.27282, train acc 0.90784, test acc 0.94820
# ------- ------- Epoch192/250 ------- -------
# loss 0.26102, train acc 0.91192, test acc 0.94640
# ------- ------- Epoch193/250 ------- -------
# loss 0.26134, train acc 0.91144, test acc 0.94900
# ------- ------- Epoch194/250 ------- -------
# loss 0.26190, train acc 0.91066, test acc 0.94850
# ------- ------- Epoch195/250 ------- -------
# loss 0.26178, train acc 0.91082, test acc 0.94700
# ------- ------- Epoch196/250 ------- -------
# loss 0.26371, train acc 0.91070, test acc 0.94890
# ------- ------- Epoch197/250 ------- -------
# loss 0.26266, train acc 0.91184, test acc 0.94850
# ------- ------- Epoch198/250 ------- -------
# loss 0.25864, train acc 0.91352, test acc 0.94830
# ------- ------- Epoch199/250 ------- -------
# loss 0.25883, train acc 0.91164, test acc 0.94800
# ------- ------- Epoch200/250 ------- -------
# loss 0.26342, train acc 0.91056, test acc 0.94840
# ------- ------- Epoch201/250 ------- -------
# loss 0.26252, train acc 0.91042, test acc 0.94750
# ------- ------- Epoch202/250 ------- -------
# loss 0.26263, train acc 0.91098, test acc 0.94830
# ------- ------- Epoch203/250 ------- -------
# loss 0.25988, train acc 0.91214, test acc 0.94760
# ------- ------- Epoch204/250 ------- -------
# loss 0.25567, train acc 0.91322, test acc 0.94840
# ------- ------- Epoch205/250 ------- -------
# loss 0.25116, train acc 0.91530, test acc 0.94740
# ------- ------- Epoch206/250 ------- -------
# loss 0.25879, train acc 0.91160, test acc 0.94720
# ------- ------- Epoch207/250 ------- -------
# loss 0.25758, train acc 0.91308, test acc 0.94750
# ------- ------- Epoch208/250 ------- -------
# loss 0.26330, train acc 0.91130, test acc 0.94830
# ------- ------- Epoch209/250 ------- -------
# loss 0.25333, train acc 0.91502, test acc 0.94720
# ------- ------- Epoch210/250 ------- -------
# loss 0.25822, train acc 0.91330, test acc 0.94910
# ------- ------- Epoch211/250 ------- -------
# loss 0.26207, train acc 0.91136, test acc 0.94740
# ------- ------- Epoch212/250 ------- -------
# loss 0.25838, train acc 0.91214, test acc 0.94780
# ------- ------- Epoch213/250 ------- -------
# loss 0.25973, train acc 0.91280, test acc 0.94810
# ------- ------- Epoch214/250 ------- -------
# loss 0.25573, train acc 0.91350, test acc 0.94930
# ------- ------- Epoch215/250 ------- -------
# loss 0.25625, train acc 0.91304, test acc 0.94850
# ------- ------- Epoch216/250 ------- -------
# loss 0.25948, train acc 0.91264, test acc 0.94800
# ------- ------- Epoch217/250 ------- -------
# loss 0.25114, train acc 0.91600, test acc 0.94820
# ------- ------- Epoch218/250 ------- -------
# loss 0.25510, train acc 0.91384, test acc 0.94810
# ------- ------- Epoch219/250 ------- -------
# loss 0.25480, train acc 0.91288, test acc 0.94730
# ------- ------- Epoch220/250 ------- -------
# loss 0.25723, train acc 0.91392, test acc 0.94830
# ------- ------- Epoch221/250 ------- -------
# loss 0.25639, train acc 0.91404, test acc 0.94820
# ------- ------- Epoch222/250 ------- -------
# loss 0.25606, train acc 0.91314, test acc 0.94800
# ------- ------- Epoch223/250 ------- -------
# loss 0.25562, train acc 0.91420, test acc 0.94800
# ------- ------- Epoch224/250 ------- -------
# loss 0.25461, train acc 0.91446, test acc 0.94830
# ------- ------- Epoch225/250 ------- -------
# loss 0.25955, train acc 0.91162, test acc 0.94770
# ------- ------- Epoch226/250 ------- -------
# loss 0.25859, train acc 0.91146, test acc 0.94750
# ------- ------- Epoch227/250 ------- -------
# loss 0.25612, train acc 0.91420, test acc 0.94790
# ------- ------- Epoch228/250 ------- -------
# loss 0.25187, train acc 0.91536, test acc 0.94880
# ------- ------- Epoch229/250 ------- -------
# loss 0.25491, train acc 0.91392, test acc 0.94790
# ------- ------- Epoch230/250 ------- -------
# loss 0.25735, train acc 0.91278, test acc 0.94770
# ------- ------- Epoch231/250 ------- -------
# loss 0.26033, train acc 0.91214, test acc 0.94840
# ------- ------- Epoch232/250 ------- -------
# loss 0.26016, train acc 0.91090, test acc 0.94730
# ------- ------- Epoch233/250 ------- -------
# loss 0.25656, train acc 0.91290, test acc 0.94790
# ------- ------- Epoch234/250 ------- -------
# loss 0.25653, train acc 0.91324, test acc 0.94780
# ------- ------- Epoch235/250 ------- -------
# loss 0.25386, train acc 0.91274, test acc 0.94850
# ------- ------- Epoch236/250 ------- -------
# loss 0.25364, train acc 0.91382, test acc 0.94870
# ------- ------- Epoch237/250 ------- -------
# loss 0.25589, train acc 0.91420, test acc 0.94940
# ------- ------- Epoch238/250 ------- -------
# loss 0.25209, train acc 0.91552, test acc 0.94780
# ------- ------- Epoch239/250 ------- -------
# loss 0.25243, train acc 0.91478, test acc 0.94740
# ------- ------- Epoch240/250 ------- -------
# loss 0.25391, train acc 0.91358, test acc 0.94830
# ------- ------- Epoch241/250 ------- -------
# loss 0.25126, train acc 0.91468, test acc 0.94840
# ------- ------- Epoch242/250 ------- -------
# loss 0.25553, train acc 0.91420, test acc 0.94830
# ------- ------- Epoch243/250 ------- -------
# loss 0.25564, train acc 0.91382, test acc 0.94700
# ------- ------- Epoch244/250 ------- -------
# loss 0.25283, train acc 0.91380, test acc 0.94840
# ------- ------- Epoch245/250 ------- -------
# loss 0.25881, train acc 0.91218, test acc 0.94710
# ------- ------- Epoch246/250 ------- -------
# loss 0.25461, train acc 0.91420, test acc 0.94920
# ------- ------- Epoch247/250 ------- -------
# loss 0.25304, train acc 0.91534, test acc 0.94790
# ------- ------- Epoch248/250 ------- -------
# loss 0.25110, train acc 0.91542, test acc 0.94800
# ------- ------- Epoch249/250 ------- -------
# loss 0.25104, train acc 0.91470, test acc 0.94790
# ------- ------- Epoch250/250 ------- -------
# loss 0.25500, train acc 0.91328, test acc 0.94830

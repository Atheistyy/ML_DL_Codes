# %%
import torch
from torch import nn
from torch.nn import functional as F
from d2l import torch as d2l
import torchvision as tv
import os
import numpy as np

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Residual(nn.Module):
    def __init__(self, input_channels, num_channels,
                 use_1x1conv=False, strides=1):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, num_channels//4,
                               kernel_size=1, padding=0)
        self.conv2 = nn.Conv2d(num_channels//4, num_channels//4,
                               kernel_size=3, padding=1,stride=strides)
        self.conv3 = nn.Conv2d(num_channels//4, num_channels,
                               kernel_size=1, padding=0)
        
        if use_1x1conv:
            self.conv4 = nn.Conv2d(input_channels, num_channels,
                                   kernel_size=1, stride=strides)
        else:
            self.conv4 = None
            
        self.bn1 = nn.BatchNorm2d(num_channels//4)
        self.bn2 = nn.BatchNorm2d(num_channels//4)
        self.bn3 = nn.BatchNorm2d(num_channels)

    def forward(self, X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = F.relu(self.bn2(self.conv2(Y)))
        Y = self.bn3(self.conv3(Y))
        
        if self.conv4:
            X = self.conv4(X)
            
        Y += X
        return F.relu(Y)

# %%
b1 = nn.Sequential(nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
                   nn.BatchNorm2d(64), nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=1, padding=1))

# %%
def resnet_block(input_channels, num_channels, num_residuals,
                 first_block=False):
    blk = []
    for i in range(num_residuals):
        if i == 0 and not first_block:
            blk.append(Residual(input_channels, num_channels,
                                use_1x1conv=True, strides=2))
        elif i == 0 and first_block:
            blk.append(Residual(input_channels, num_channels,
                                use_1x1conv=True))
        else:
            blk.append(Residual(num_channels, num_channels))
    return blk

# %%
b2 = nn.Sequential(*resnet_block(64, 256, 3, first_block=True))
b3 = nn.Sequential(*resnet_block(256, 512, 4))
b4 = nn.Sequential(*resnet_block(512, 1024, 6))
b5 = nn.Sequential(*resnet_block(1024, 2048, 3))

# %%
net = nn.Sequential(b1, b2, b3, b4, b5,
                    nn.AdaptiveAvgPool2d((1,1)),
                    nn.Flatten(), nn.Dropout(0.25), nn.Linear(2048, 10))

if device == 'cuda':
	net = torch.nn.DataParallel(net)

# %%
X = torch.rand(size=(1, 3, 32, 32))
for layer in net:
    X = layer(X)
    print(layer.__class__.__name__,'output shape:\t', X.shape)
# Out:
# Sequential output shape:	 torch.Size([1, 64, 32, 32])
# Sequential output shape:	 torch.Size([1, 256, 32, 32])
# Sequential output shape:	 torch.Size([1, 512, 16, 16])
# Sequential output shape:	 torch.Size([1, 1024, 8, 8])
# Sequential output shape:	 torch.Size([1, 2048, 4, 4])
# AdaptiveAvgPool2d output shape:	 torch.Size([1, 2048, 1, 1])
# Flatten output shape:	 torch.Size([1, 2048])
# Dropout output shape:	 torch.Size([1, 2048])
# Linear output shape:	 torch.Size([1, 10])

# %%
def evaluate_accuracy_gpu(net, data_iter, device=None): 
    if isinstance(net, nn.Module):
        net.eval()  
        if not device:
            device = next(iter(net.parameters())).device
    metric = d2l.Accumulator(2)
    with torch.no_grad():
        for X, y in data_iter:
            if isinstance(X, list):
                X = [x.to(device) for x in X]
            else:
                X = X.to(device)
            y = y.to(device)
            metric.add(d2l.accuracy(net(X), y), y.numel())
    return metric[0] / metric[1]

# %%
def train_net(net, train_iter, test_iter, num_epochs, lr, device):
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            torch.nn.init.kaiming_uniform_(m.weight)
    net.apply(init_weights)
    print('training on', device)
    net.to(device)
    optimizer = torch.optim.SGD(params=net.parameters(),
                          lr=lr,
                          momentum=0.9,
                          weight_decay=0.001)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(
        optimizer, milestones=[50, 100, 150], gamma=0.1)
    loss = nn.CrossEntropyLoss()
    num_batches = len(train_iter)
    for epoch in range(num_epochs):
        metric = d2l.Accumulator(3)
        net.train()
        for i, (X, y) in enumerate(train_iter):
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            optimizer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
        scheduler.step()
        test_acc = evaluate_accuracy_gpu(net, test_iter)
        print(f'------- ------- Epoch{epoch+1}/{num_epochs} ------- -------')
        print(f'loss {train_l:.5f}, train acc {train_acc:.5f}, '
          f'test acc {test_acc:.5f}')

# %%
shape_aug = tv.transforms.RandomResizedCrop(
    (28, 28), scale=(0.1, 1), ratio=(0.5, 2))

# %%
train_augs = tv.transforms.Compose([
    tv.transforms.RandomCrop(32, padding=4),
    tv.transforms.RandomHorizontalFlip(),
    tv.transforms.ToTensor(), shape_aug,
    tv.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

test_augs = tv.transforms.Compose([
    tv.transforms.ToTensor(), 
    tv.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# %%
def load_cifar10(is_train, augs, batch_size):
    dataset = tv.datasets.CIFAR10(root="../data", train=is_train,
                                           transform=augs, download=True)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                    shuffle=is_train, num_workers=2)
    return dataloader

# %%
lr, num_epochs, batch_size = 0.01, 200, 128

# %%
train_iter = load_cifar10(True, train_augs, batch_size)
test_iter = load_cifar10(False, test_augs, batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_net(net, train_iter, test_iter, num_epochs, lr, device)
# Out:
# training on cuda
# ------- ------- Epoch1/200 ------- -------
# loss 3.40733, train acc 0.18326, test acc 0.31320
# ------- ------- Epoch2/200 ------- -------
# loss 2.05797, train acc 0.27400, test acc 0.36030
# ------- ------- Epoch3/200 ------- -------
# loss 1.86335, train acc 0.32742, test acc 0.41460
# ------- ------- Epoch4/200 ------- -------
# loss 1.76549, train acc 0.36428, test acc 0.43320
# ------- ------- Epoch5/200 ------- -------
# loss 1.68314, train acc 0.38964, test acc 0.46890
# ------- ------- Epoch6/200 ------- -------
# loss 1.60910, train acc 0.41830, test acc 0.47560
# ------- ------- Epoch7/200 ------- -------
# loss 1.54691, train acc 0.44454, test acc 0.47340
# ------- ------- Epoch8/200 ------- -------
# loss 1.48863, train acc 0.46638, test acc 0.53590
# ------- ------- Epoch9/200 ------- -------
# loss 1.43597, train acc 0.48660, test acc 0.55680
# ------- ------- Epoch10/200 ------- -------
# loss 1.38013, train acc 0.50632, test acc 0.57820
# ------- ------- Epoch11/200 ------- -------
# loss 1.34596, train acc 0.52056, test acc 0.54790
# ------- ------- Epoch12/200 ------- -------
# loss 1.30653, train acc 0.53396, test acc 0.61880
# ------- ------- Epoch13/200 ------- -------
# loss 1.27296, train acc 0.54898, test acc 0.62980
# ------- ------- Epoch14/200 ------- -------
# loss 1.22945, train acc 0.56554, test acc 0.64600
# ------- ------- Epoch15/200 ------- -------
# loss 1.20249, train acc 0.57262, test acc 0.62450
# ------- ------- Epoch16/200 ------- -------
# loss 1.17172, train acc 0.58596, test acc 0.68230
# ------- ------- Epoch17/200 ------- -------
# loss 1.14482, train acc 0.59680, test acc 0.67530
# ------- ------- Epoch18/200 ------- -------
# loss 1.11825, train acc 0.60814, test acc 0.66590
# ------- ------- Epoch19/200 ------- -------
# loss 1.09332, train acc 0.61472, test acc 0.67280
# ------- ------- Epoch20/200 ------- -------
# loss 1.06458, train acc 0.62748, test acc 0.68850
# ------- ------- Epoch21/200 ------- -------
# loss 1.03450, train acc 0.63488, test acc 0.72750
# ------- ------- Epoch22/200 ------- -------
# loss 1.01932, train acc 0.64330, test acc 0.74930
# ------- ------- Epoch23/200 ------- -------
# loss 0.99466, train acc 0.65282, test acc 0.70900
# ------- ------- Epoch24/200 ------- -------
# loss 0.98413, train acc 0.65460, test acc 0.73290
# ------- ------- Epoch25/200 ------- -------
# loss 0.95694, train acc 0.66542, test acc 0.75540
# ------- ------- Epoch26/200 ------- -------
# loss 0.94259, train acc 0.66900, test acc 0.76110
# ------- ------- Epoch27/200 ------- -------
# loss 0.92651, train acc 0.67604, test acc 0.75930
# ------- ------- Epoch28/200 ------- -------
# loss 0.91279, train acc 0.68214, test acc 0.77090
# ------- ------- Epoch29/200 ------- -------
# loss 0.90001, train acc 0.68606, test acc 0.72780
# ------- ------- Epoch30/200 ------- -------
# loss 0.87911, train acc 0.69164, test acc 0.80710
# ------- ------- Epoch31/200 ------- -------
# loss 0.87383, train acc 0.69670, test acc 0.78920
# ------- ------- Epoch32/200 ------- -------
# loss 0.85803, train acc 0.70158, test acc 0.79940
# ------- ------- Epoch33/200 ------- -------
# loss 0.85613, train acc 0.70104, test acc 0.81950
# ------- ------- Epoch34/200 ------- -------
# loss 0.84002, train acc 0.70762, test acc 0.78540
# ------- ------- Epoch35/200 ------- -------
# loss 0.82702, train acc 0.71264, test acc 0.79180
# ------- ------- Epoch36/200 ------- -------
# loss 0.82342, train acc 0.71262, test acc 0.80730
# ------- ------- Epoch37/200 ------- -------
# loss 0.81565, train acc 0.71520, test acc 0.83020
# ------- ------- Epoch38/200 ------- -------
# loss 0.81330, train acc 0.71536, test acc 0.80880
# ------- ------- Epoch39/200 ------- -------
# loss 0.80510, train acc 0.71946, test acc 0.82560
# ------- ------- Epoch40/200 ------- -------
# loss 0.79420, train acc 0.72336, test acc 0.82190
# ------- ------- Epoch41/200 ------- -------
# loss 0.78560, train acc 0.72584, test acc 0.82520
# ------- ------- Epoch42/200 ------- -------
# loss 0.78450, train acc 0.72484, test acc 0.82210
# ------- ------- Epoch43/200 ------- -------
# loss 0.77325, train acc 0.73106, test acc 0.81500
# ------- ------- Epoch44/200 ------- -------
# loss 0.76404, train acc 0.73440, test acc 0.83500
# ------- ------- Epoch45/200 ------- -------
# loss 0.76561, train acc 0.73330, test acc 0.83240
# ------- ------- Epoch46/200 ------- -------
# loss 0.75657, train acc 0.73658, test acc 0.78910
# ------- ------- Epoch47/200 ------- -------
# loss 0.76004, train acc 0.73476, test acc 0.84120
# ------- ------- Epoch48/200 ------- -------
# loss 0.75332, train acc 0.73908, test acc 0.83850
# ------- ------- Epoch49/200 ------- -------
# loss 0.74621, train acc 0.74084, test acc 0.83270
# ------- ------- Epoch50/200 ------- -------
# loss 0.74481, train acc 0.74100, test acc 0.79450
# ------- ------- Epoch51/200 ------- -------
# loss 0.62185, train acc 0.78634, test acc 0.89560
# ------- ------- Epoch52/200 ------- -------
# loss 0.56834, train acc 0.80412, test acc 0.89940
# ------- ------- Epoch53/200 ------- -------
# loss 0.55979, train acc 0.80550, test acc 0.90310
# ------- ------- Epoch54/200 ------- -------
# loss 0.53641, train acc 0.81420, test acc 0.90740
# ------- ------- Epoch55/200 ------- -------
# loss 0.53596, train acc 0.81570, test acc 0.91020
# ------- ------- Epoch56/200 ------- -------
# loss 0.52493, train acc 0.81908, test acc 0.91140
# ------- ------- Epoch57/200 ------- -------
# loss 0.51934, train acc 0.82010, test acc 0.90890
# ------- ------- Epoch58/200 ------- -------
# loss 0.51044, train acc 0.82248, test acc 0.90770
# ------- ------- Epoch59/200 ------- -------
# loss 0.51003, train acc 0.82558, test acc 0.91240
# ------- ------- Epoch60/200 ------- -------
# loss 0.50377, train acc 0.82690, test acc 0.91220
# ------- ------- Epoch61/200 ------- -------
# loss 0.49876, train acc 0.82766, test acc 0.91320
# ------- ------- Epoch62/200 ------- -------
# loss 0.49006, train acc 0.83064, test acc 0.91250
# ------- ------- Epoch63/200 ------- -------
# loss 0.48560, train acc 0.83320, test acc 0.91290
# ------- ------- Epoch64/200 ------- -------
# loss 0.49115, train acc 0.82990, test acc 0.91210
# ------- ------- Epoch65/200 ------- -------
# loss 0.47962, train acc 0.83400, test acc 0.91470
# ------- ------- Epoch66/200 ------- -------
# loss 0.47569, train acc 0.83534, test acc 0.91460
# ------- ------- Epoch67/200 ------- -------
# loss 0.47599, train acc 0.83422, test acc 0.91270
# ------- ------- Epoch68/200 ------- -------
# loss 0.47357, train acc 0.83458, test acc 0.91230
# ------- ------- Epoch69/200 ------- -------
# loss 0.46825, train acc 0.83806, test acc 0.91530
# ------- ------- Epoch70/200 ------- -------
# loss 0.46670, train acc 0.83790, test acc 0.91390
# ------- ------- Epoch71/200 ------- -------
# loss 0.46109, train acc 0.84222, test acc 0.91560
# ------- ------- Epoch72/200 ------- -------
# loss 0.46006, train acc 0.83936, test acc 0.91130
# ------- ------- Epoch73/200 ------- -------
# loss 0.45941, train acc 0.84056, test acc 0.91950
# ------- ------- Epoch74/200 ------- -------
# loss 0.45765, train acc 0.84206, test acc 0.91970
# ------- ------- Epoch75/200 ------- -------
# loss 0.45260, train acc 0.84292, test acc 0.91840
# ------- ------- Epoch76/200 ------- -------
# loss 0.45853, train acc 0.84074, test acc 0.91580
# ------- ------- Epoch77/200 ------- -------
# loss 0.45200, train acc 0.84458, test acc 0.92000
# ------- ------- Epoch78/200 ------- -------
# loss 0.44918, train acc 0.84356, test acc 0.92110
# ------- ------- Epoch79/200 ------- -------
# loss 0.44538, train acc 0.84618, test acc 0.91970
# ------- ------- Epoch80/200 ------- -------
# loss 0.44582, train acc 0.84604, test acc 0.91610
# ------- ------- Epoch81/200 ------- -------
# loss 0.43658, train acc 0.85074, test acc 0.91940
# ------- ------- Epoch82/200 ------- -------
# loss 0.43731, train acc 0.84912, test acc 0.91950
# ------- ------- Epoch83/200 ------- -------
# loss 0.43862, train acc 0.84908, test acc 0.91500
# ------- ------- Epoch84/200 ------- -------
# loss 0.43142, train acc 0.85092, test acc 0.91880
# ------- ------- Epoch85/200 ------- -------
# loss 0.43562, train acc 0.84902, test acc 0.91200
# ------- ------- Epoch86/200 ------- -------
# loss 0.43236, train acc 0.85090, test acc 0.91460
# ------- ------- Epoch87/200 ------- -------
# loss 0.42588, train acc 0.85182, test acc 0.92030
# ------- ------- Epoch88/200 ------- -------
# loss 0.43048, train acc 0.85260, test acc 0.92110
# ------- ------- Epoch89/200 ------- -------
# loss 0.42415, train acc 0.85374, test acc 0.91580
# ------- ------- Epoch90/200 ------- -------
# loss 0.42669, train acc 0.85298, test acc 0.91630
# ------- ------- Epoch91/200 ------- -------
# loss 0.42796, train acc 0.85114, test acc 0.91860
# ------- ------- Epoch92/200 ------- -------
# loss 0.42018, train acc 0.85464, test acc 0.91900
# ------- ------- Epoch93/200 ------- -------
# loss 0.41596, train acc 0.85618, test acc 0.92070
# ------- ------- Epoch94/200 ------- -------
# loss 0.41823, train acc 0.85560, test acc 0.91890
# ------- ------- Epoch95/200 ------- -------
# loss 0.42100, train acc 0.85440, test acc 0.92110
# ------- ------- Epoch96/200 ------- -------
# loss 0.41616, train acc 0.85774, test acc 0.91760
# ------- ------- Epoch97/200 ------- -------
# loss 0.42323, train acc 0.85224, test acc 0.92170
# ------- ------- Epoch98/200 ------- -------
# loss 0.40912, train acc 0.85938, test acc 0.92410
# ------- ------- Epoch99/200 ------- -------
# loss 0.42095, train acc 0.85504, test acc 0.91950
# ------- ------- Epoch100/200 ------- -------
# loss 0.41076, train acc 0.85744, test acc 0.91680
# ------- ------- Epoch101/200 ------- -------
# loss 0.38833, train acc 0.86684, test acc 0.92790
# ------- ------- Epoch102/200 ------- -------
# loss 0.37441, train acc 0.87236, test acc 0.92940
# ------- ------- Epoch103/200 ------- -------
# loss 0.36462, train acc 0.87570, test acc 0.92870
# ------- ------- Epoch104/200 ------- -------
# loss 0.36107, train acc 0.87554, test acc 0.92840
# ------- ------- Epoch105/200 ------- -------
# loss 0.35949, train acc 0.87706, test acc 0.92930
# ------- ------- Epoch106/200 ------- -------
# loss 0.36527, train acc 0.87488, test acc 0.92900
# ------- ------- Epoch107/200 ------- -------
# loss 0.35304, train acc 0.87976, test acc 0.92930
# ------- ------- Epoch108/200 ------- -------
# loss 0.35340, train acc 0.87962, test acc 0.92890
# ------- ------- Epoch109/200 ------- -------
# loss 0.35224, train acc 0.88050, test acc 0.92990
# ------- ------- Epoch110/200 ------- -------
# loss 0.34666, train acc 0.88272, test acc 0.93060
# ------- ------- Epoch111/200 ------- -------
# loss 0.35549, train acc 0.87848, test acc 0.92880
# ------- ------- Epoch112/200 ------- -------
# loss 0.35136, train acc 0.88048, test acc 0.93060
# ------- ------- Epoch113/200 ------- -------
# loss 0.34384, train acc 0.88246, test acc 0.93070
# ------- ------- Epoch114/200 ------- -------
# loss 0.34893, train acc 0.88000, test acc 0.92960
# ------- ------- Epoch115/200 ------- -------
# loss 0.34729, train acc 0.88106, test acc 0.93100
# ------- ------- Epoch116/200 ------- -------
# loss 0.34702, train acc 0.88188, test acc 0.93170
# ------- ------- Epoch117/200 ------- -------
# loss 0.35039, train acc 0.87924, test acc 0.93020
# ------- ------- Epoch118/200 ------- -------
# loss 0.34030, train acc 0.88412, test acc 0.93020
# ------- ------- Epoch119/200 ------- -------
# loss 0.34260, train acc 0.88192, test acc 0.92990
# ------- ------- Epoch120/200 ------- -------
# loss 0.34307, train acc 0.88104, test acc 0.93090
# ------- ------- Epoch121/200 ------- -------
# loss 0.33681, train acc 0.88480, test acc 0.92940
# ------- ------- Epoch122/200 ------- -------
# loss 0.34029, train acc 0.88332, test acc 0.92950
# ------- ------- Epoch123/200 ------- -------
# loss 0.33517, train acc 0.88388, test acc 0.93030
# ------- ------- Epoch124/200 ------- -------
# loss 0.34100, train acc 0.88286, test acc 0.92980
# ------- ------- Epoch125/200 ------- -------
# loss 0.33947, train acc 0.88328, test acc 0.93190
# ------- ------- Epoch126/200 ------- -------
# loss 0.33805, train acc 0.88478, test acc 0.93060
# ------- ------- Epoch127/200 ------- -------
# loss 0.33953, train acc 0.88362, test acc 0.93150
# ------- ------- Epoch128/200 ------- -------
# loss 0.33926, train acc 0.88412, test acc 0.92980
# ------- ------- Epoch129/200 ------- -------
# loss 0.33669, train acc 0.88392, test acc 0.93200
# ------- ------- Epoch130/200 ------- -------
# loss 0.34200, train acc 0.88116, test acc 0.93280
# ------- ------- Epoch131/200 ------- -------
# loss 0.33500, train acc 0.88428, test acc 0.93170
# ------- ------- Epoch132/200 ------- -------
# loss 0.33133, train acc 0.88524, test acc 0.93150
# ------- ------- Epoch133/200 ------- -------
# loss 0.33535, train acc 0.88416, test acc 0.93130
# ------- ------- Epoch134/200 ------- -------
# loss 0.33588, train acc 0.88344, test acc 0.93180
# ------- ------- Epoch135/200 ------- -------
# loss 0.33008, train acc 0.88692, test acc 0.93260
# ------- ------- Epoch136/200 ------- -------
# loss 0.33095, train acc 0.88542, test acc 0.93260
# ------- ------- Epoch137/200 ------- -------
# loss 0.33084, train acc 0.88708, test acc 0.93280
# ------- ------- Epoch138/200 ------- -------
# loss 0.33006, train acc 0.88610, test acc 0.93210
# ------- ------- Epoch139/200 ------- -------
# loss 0.33510, train acc 0.88452, test acc 0.93100
# ------- ------- Epoch140/200 ------- -------
# loss 0.32553, train acc 0.88812, test acc 0.93190
# ------- ------- Epoch141/200 ------- -------
# loss 0.32879, train acc 0.88658, test acc 0.93160
# ------- ------- Epoch142/200 ------- -------
# loss 0.32568, train acc 0.88756, test acc 0.93300
# ------- ------- Epoch143/200 ------- -------
# loss 0.33155, train acc 0.88696, test acc 0.93050
# ------- ------- Epoch144/200 ------- -------
# loss 0.32327, train acc 0.88870, test acc 0.93050
# ------- ------- Epoch145/200 ------- -------
# loss 0.32717, train acc 0.88776, test acc 0.93270
# ------- ------- Epoch146/200 ------- -------
# loss 0.32616, train acc 0.88822, test acc 0.93300
# ------- ------- Epoch147/200 ------- -------
# loss 0.32542, train acc 0.88862, test acc 0.93430
# ------- ------- Epoch148/200 ------- -------
# loss 0.32581, train acc 0.88702, test acc 0.93300
# ------- ------- Epoch149/200 ------- -------
# loss 0.32516, train acc 0.88946, test acc 0.93360
# ------- ------- Epoch150/200 ------- -------
# loss 0.32170, train acc 0.88956, test acc 0.93260
# ------- ------- Epoch151/200 ------- -------
# loss 0.32442, train acc 0.88908, test acc 0.93320
# ------- ------- Epoch152/200 ------- -------
# loss 0.32645, train acc 0.88802, test acc 0.93250
# ------- ------- Epoch153/200 ------- -------
# loss 0.32684, train acc 0.88648, test acc 0.93320
# ------- ------- Epoch154/200 ------- -------
# loss 0.32507, train acc 0.88922, test acc 0.93200
# ------- ------- Epoch155/200 ------- -------
# loss 0.31624, train acc 0.89272, test acc 0.93170
# ------- ------- Epoch156/200 ------- -------
# loss 0.31741, train acc 0.89010, test acc 0.93210
# ------- ------- Epoch157/200 ------- -------
# loss 0.32273, train acc 0.89010, test acc 0.93350
# ------- ------- Epoch158/200 ------- -------
# loss 0.32229, train acc 0.89088, test acc 0.93300
# ------- ------- Epoch159/200 ------- -------
# loss 0.32027, train acc 0.89006, test acc 0.93360
# ------- ------- Epoch160/200 ------- -------
# loss 0.32397, train acc 0.88934, test acc 0.93320
# ------- ------- Epoch161/200 ------- -------
# loss 0.32368, train acc 0.89040, test acc 0.93290
# ------- ------- Epoch162/200 ------- -------
# loss 0.32033, train acc 0.89112, test acc 0.93330
# ------- ------- Epoch163/200 ------- -------
# loss 0.31790, train acc 0.89136, test acc 0.93160
# ------- ------- Epoch164/200 ------- -------
# loss 0.31934, train acc 0.89116, test acc 0.93250
# ------- ------- Epoch165/200 ------- -------
# loss 0.31755, train acc 0.89128, test acc 0.93280
# ------- ------- Epoch166/200 ------- -------
# loss 0.31467, train acc 0.89176, test acc 0.93300
# ------- ------- Epoch167/200 ------- -------
# loss 0.32025, train acc 0.88938, test acc 0.93260
# ------- ------- Epoch168/200 ------- -------
# loss 0.31721, train acc 0.89116, test acc 0.93250
# ------- ------- Epoch169/200 ------- -------
# loss 0.31656, train acc 0.89110, test acc 0.93300
# ------- ------- Epoch170/200 ------- -------
# loss 0.31347, train acc 0.89302, test acc 0.93290
# ------- ------- Epoch171/200 ------- -------
# loss 0.31527, train acc 0.89150, test acc 0.93360
# ------- ------- Epoch172/200 ------- -------
# loss 0.31173, train acc 0.89492, test acc 0.93350
# ------- ------- Epoch173/200 ------- -------
# loss 0.31702, train acc 0.89126, test acc 0.93350
# ------- ------- Epoch174/200 ------- -------
# loss 0.32188, train acc 0.88928, test acc 0.93280
# ------- ------- Epoch175/200 ------- -------
# loss 0.32025, train acc 0.89102, test acc 0.93250
# ------- ------- Epoch176/200 ------- -------
# loss 0.31983, train acc 0.89042, test acc 0.93210
# ------- ------- Epoch177/200 ------- -------
# loss 0.31791, train acc 0.89150, test acc 0.93250
# ------- ------- Epoch178/200 ------- -------
# loss 0.32312, train acc 0.88928, test acc 0.93250
# ------- ------- Epoch179/200 ------- -------
# loss 0.31751, train acc 0.89136, test acc 0.93380
# ------- ------- Epoch180/200 ------- -------
# loss 0.31664, train acc 0.89134, test acc 0.93310
# ------- ------- Epoch181/200 ------- -------
# loss 0.31437, train acc 0.89144, test acc 0.93330
# ------- ------- Epoch182/200 ------- -------
# loss 0.31999, train acc 0.89026, test acc 0.93220
# ------- ------- Epoch183/200 ------- -------
# loss 0.31217, train acc 0.89286, test acc 0.93320
# ------- ------- Epoch184/200 ------- -------
# loss 0.31477, train acc 0.89152, test acc 0.93310
# ------- ------- Epoch185/200 ------- -------
# loss 0.31347, train acc 0.89198, test acc 0.93380
# ------- ------- Epoch186/200 ------- -------
# loss 0.31687, train acc 0.89156, test acc 0.93360
# ------- ------- Epoch187/200 ------- -------
# loss 0.32072, train acc 0.89030, test acc 0.93250
# ------- ------- Epoch188/200 ------- -------
# loss 0.32019, train acc 0.89092, test acc 0.93400
# ------- ------- Epoch189/200 ------- -------
# loss 0.30888, train acc 0.89460, test acc 0.93230
# ------- ------- Epoch190/200 ------- -------
# loss 0.31259, train acc 0.89342, test acc 0.93340
# ------- ------- Epoch191/200 ------- -------
# loss 0.31771, train acc 0.89190, test acc 0.93300
# ------- ------- Epoch192/200 ------- -------
# loss 0.31535, train acc 0.89186, test acc 0.93410
# ------- ------- Epoch193/200 ------- -------
# loss 0.31643, train acc 0.89174, test acc 0.93400
# ------- ------- Epoch194/200 ------- -------
# loss 0.31477, train acc 0.89298, test acc 0.93330
# ------- ------- Epoch195/200 ------- -------
# loss 0.31458, train acc 0.89124, test acc 0.93280
# ------- ------- Epoch196/200 ------- -------
# loss 0.31374, train acc 0.89212, test acc 0.93340
# ------- ------- Epoch197/200 ------- -------
# loss 0.31772, train acc 0.89078, test acc 0.93350
# ------- ------- Epoch198/200 ------- -------
# loss 0.31400, train acc 0.89402, test acc 0.93400
# ------- ------- Epoch199/200 ------- -------
# loss 0.31820, train acc 0.88978, test acc 0.93410
# ------- ------- Epoch200/200 ------- -------
# loss 0.31742, train acc 0.89060, test acc 0.93400
